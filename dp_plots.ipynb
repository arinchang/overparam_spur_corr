# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Weight Decay 0.0001 Varying Width Results with DP noise_mult = 1.0 and max_grad_clip = 1.0

# %%
dp_1 = pd.read_csv('logs/test_dp_width1.csv')
dp_4 = pd.read_csv('logs/test_dp_width4.csv')
dp_16 = pd.read_csv('logs/test_dp_width16.csv')
dp_32 = pd.read_csv('logs/test_dp_width32.csv')
dp_64 = pd.read_csv('logs/test_dp_width64.csv')
dp_96 = pd.read_csv('logs/test_dp_width96.csv')

# %%
w1_worst_group = np.mean(np.array(dp_1['avg_loss_group:3'])[40:])
w4_worst_group = np.mean(np.array(dp_4['avg_loss_group:3'])[40:])
w16_worst_group = np.mean(np.array(dp_16['avg_loss_group:3'])[40:])
w32_worst_group = np.mean(np.array(dp_32['avg_loss_group:3'])[40:])
w64_worst_group = np.mean(np.array(dp_64['avg_loss_group:3'])[40:])
w96_worst_group = np.mean(np.array(dp_96['avg_loss_group:3'])[40:])

# %%
dp_1['avg_actual_loss'][49]
# Out:
# 0.8625214695930481

# %%
test_errors = np.array([dp_1['avg_actual_loss'][49], dp_4['avg_actual_loss'][49], dp_16['avg_actual_loss'][49], dp_32['avg_actual_loss'][49], dp_64['avg_actual_loss'][49], dp_96['avg_actual_loss'][49]])
worst_group_errors = np.array([w1_worst_group, w4_worst_group, w16_worst_group, w32_worst_group, w64_worst_group, w96_worst_group])
plt.plot(np.array([1, 4, 16, 32, 64, 96]), test_errors, marker='o', label='average test')
plt.plot(np.array([1, 4, 16, 32, 64, 96]), worst_group_errors, marker='o', label='worst-group test')
plt.title("CelebA with 0.0001 Weight Decay and DP with reweighting")
plt.xlabel("ResNet Width")
plt.ylabel("Error")
plt.legend()

# %%
plt.plot(dp_32['avg_loss_group:0'], label='group 0')
plt.plot(dp_32['avg_loss_group:1'], label='group 1')
plt.plot(dp_32['avg_loss_group:2'], label='group 2')
plt.plot(dp_32['avg_loss_group:3'], label='group 3')
plt.title("celebA test error per group, width 32")
plt.xlabel("epoch")
plt.ylabel("error")
plt.legend()

# %%
plt.plot(dp_64['avg_loss_group:0'], label='group 0')
plt.plot(dp_64['avg_loss_group:1'], label='group 1')
plt.plot(dp_64['avg_loss_group:2'], label='group 2')
plt.plot(dp_64['avg_loss_group:3'], label='group 3')
plt.title("celebA test error per group, width 64")
plt.xlabel("epoch")
plt.ylabel("error")
plt.legend()

# %%
dp_1_train = pd.read_csv("logs/train_dp_width1.csv")
dp_1_train = dp_1_train.groupby(['epoch']).mean()

dp_4_train = pd.read_csv("logs/train_dp_width4.csv")
dp_4_train = dp_4_train.groupby(['epoch']).mean()

dp_16_train = pd.read_csv("logs/train_dp_width16.csv")
dp_16_train = dp_16_train.groupby(['epoch']).mean()

dp_32_train = pd.read_csv("logs/train_dp_width32.csv")
dp_32_train = dp_32_train.groupby(['epoch']).mean()

dp_64_train = pd.read_csv("logs/train_dp_width64.csv")
dp_64_train = dp_64_train.groupby(['epoch']).mean()

dp_96_train = pd.read_csv("logs/train_dp_width96.csv")
dp_96_train = dp_96_train.groupby(['epoch']).mean()

# %%
plt.plot(dp_1_train['avg_actual_loss'], label="width 1")
plt.plot(dp_4_train['avg_actual_loss'], label="width 4")
plt.plot(dp_16_train['avg_actual_loss'], label="width 16")
plt.plot(dp_32_train['avg_actual_loss'], label="width 32")
plt.plot(dp_64_train['avg_actual_loss'], label="width 64")
plt.plot(dp_96_train['avg_actual_loss'], label="width 96")

plt.title("Training Curves for Varying Widths, Weight Decay 0.0001 with DP")
plt.xlabel("epoch")
plt.ylabel('error')
plt.legend()

# %%
# plot the privacy budget expenditures

# %% [markdown]
# ## DP-SGD with ERM

# %%
dp_1_erm = pd.read_csv('logs/test_dp_width1_erm.csv')
dp_4_erm = pd.read_csv('logs/test_dp_width4_erm.csv')
dp_16_erm = pd.read_csv('logs/test_dp_width16_erm.csv')
dp_32_erm = pd.read_csv('logs/test_dp_width32_erm.csv')
dp_64_erm = pd.read_csv('logs/test_dp_width64_erm.csv')
dp_96_erm = pd.read_csv('logs/test_dp_width96_erm.csv')

# %%
w1_worst_group_erm = np.mean(np.array(dp_1_erm['avg_loss_group:3'])[40:])
w4_worst_group_erm = np.mean(np.array(dp_4_erm['avg_loss_group:3'])[40:])
w16_worst_group_erm = np.mean(np.array(dp_16_erm['avg_loss_group:3'])[40:])
w32_worst_group_erm = np.mean(np.array(dp_32_erm['avg_loss_group:3'])[40:])
w64_worst_group_erm = np.mean(np.array(dp_64_erm['avg_loss_group:3'])[40:])
w96_worst_group_erm = np.mean(np.array(dp_96_erm['avg_loss_group:3'])[40:])

# %%
test_errors = np.array([dp_1_erm['avg_actual_loss'][49], dp_4_erm['avg_actual_loss'][49], dp_16_erm['avg_actual_loss'][49], dp_32_erm['avg_actual_loss'][49], dp_64_erm['avg_actual_loss'][49], dp_96_erm['avg_actual_loss'][45]])
worst_group_errors = np.array([w1_worst_group_erm, w4_worst_group_erm, w16_worst_group_erm, w32_worst_group_erm, w64_worst_group_erm, w96_worst_group_erm])
plt.plot(np.array([1, 4, 16, 32, 64, 96]), test_errors, marker='o', label='average test')
plt.plot(np.array([1, 4, 16, 32, 64, 96]), worst_group_errors, marker='o', label='worst-group test')
plt.title("CelebA with 0.0001 Weight Decay and DP, no reweighting")
plt.xlabel("ResNet Width")
plt.ylabel("Error")
plt.legend()

# %%
wd0001_w1_erm = pd.read_csv('logs/test_wd0001_w1_erm.csv')
wd0001_w4_erm = pd.read_csv('logs/test_wd0001_w4_erm.csv')
wd0001_w16_erm = pd.read_csv('logs/test_wd0001_w16_erm.csv')
wd0001_w32_erm = pd.read_csv('logs/test_wd0001_w32_erm.csv')
wd0001_w64_erm = pd.read_csv('logs/test_wd0001_w64_erm.csv')
wd0001_w96_erm = pd.read_csv('logs/test_wd0001_w96_erm.csv')

# %%
wd0001_w1_worst_group_erm = np.mean(np.array(wd0001_w1_erm['avg_loss_group:3'])[40:])
wd0001_w4_worst_group_erm = np.mean(np.array(wd0001_w4_erm['avg_loss_group:3'])[40:])
wd0001_w16_worst_group_erm = np.mean(np.array(wd0001_w16_erm['avg_loss_group:3'])[40:])
wd0001_w32_worst_group_erm = np.mean(np.array(wd0001_w32_erm['avg_loss_group:3'])[40:])
wd0001_w64_worst_group_erm = np.mean(np.array(wd0001_w64_erm['avg_loss_group:3'])[40:])
wd0001_w96_worst_group_erm = np.mean(np.array(wd0001_w96_erm['avg_loss_group:3'])[40:])

# %%
test_errors = np.array([wd0001_w1_erm['avg_actual_loss'][49], wd0001_w4_erm['avg_actual_loss'][49], wd0001_w16_erm['avg_actual_loss'][49], wd0001_w32_erm['avg_actual_loss'][49], wd0001_w64_erm['avg_actual_loss'][49], wd0001_w96_erm['avg_actual_loss'][49]])
worst_group_errors = np.array([wd0001_w1_worst_group_erm, wd0001_w4_worst_group_erm, wd0001_w16_worst_group_erm, wd0001_w32_worst_group_erm, wd0001_w64_worst_group_erm, wd0001_w96_worst_group_erm])
plt.plot(np.array([1, 4, 16, 32, 64, 96]), test_errors, marker='o', label='average test')
plt.plot(np.array([1, 4, 16, 32, 64, 96]), worst_group_errors, marker='o', label='worst-group test')
plt.title("CelebA with 0.0001 Weight Decay ERM")
plt.xlabel("ResNet Width")
plt.ylabel("Error")
plt.legend()

# %% [markdown]
# ## Plots for Varying DP noise added for width 32

# %%
dpw32_n07 = pd.read_csv('logs/test_dp_width32_noise07.csv')
dpw32_n08 = pd.read_csv('logs/test_dp_width32_noise08.csv')
dpw32_n09 = pd.read_csv('logs/test_dp_width32_noise09.csv')
dpw32_n11 = pd.read_csv('logs/test_dp_width32_noise11.csv')
dpw32_n12 = pd.read_csv('logs/test_dp_width32_noise12.csv')
dpw32_n13 = pd.read_csv('logs/test_dp_width32_noise13.csv')

# %%
dpw32_n07_worst_group = np.mean(np.array(dpw32_n07['avg_loss_group:3'])[40:])
dpw32_n08_worst_group = np.mean(np.array(dpw32_n08['avg_loss_group:3'])[40:])
dpw32_n09_worst_group = np.mean(np.array(dpw32_n09['avg_loss_group:3'])[40:])
dpw32_n11_worst_group = np.mean(np.array(dpw32_n11['avg_loss_group:3'])[40:])
dpw32_n12_worst_group = np.mean(np.array(dpw32_n12['avg_loss_group:3'])[40:])
dpw32_n13_worst_group = np.mean(np.array(dpw32_n13['avg_loss_group:3'])[40:])

# %%
test_errors = np.array([dpw32_n07['avg_actual_loss'][49], dpw32_n08['avg_actual_loss'][49], dpw32_n09['avg_actual_loss'][49], dpw32_n11['avg_actual_loss'][49], dpw32_n12['avg_actual_loss'][49], dpw32_n13['avg_actual_loss'][49]])
worst_group_errors = np.array([dpw32_n07_worst_group, dpw32_n08_worst_group, dpw32_n09_worst_group, dpw32_n11_worst_group, dpw32_n12_worst_group, dpw32_n13_worst_group])
plt.plot(np.array([0.7, 0.8, 0.9, 1.1, 1.2, 1.3]), test_errors, marker='o', label='average test')
plt.plot(np.array([0.7, 0.8, 0.9, 1.1, 1.2, 1.3]), worst_group_errors, marker='o', label='worst-group test')
plt.title("CelebA with 0.0001 Weight Decay, Varying DP noise")
plt.xlabel("DP-Noise_mult")
plt.ylabel("Error")
plt.legend()

# %%
dpw32_n07_reweight = pd.read_csv('logs/test_dp_w32_n07_reweight.csv')
dpw32_n08_reweight = pd.read_csv('logs/test_dp_w32_n08_reweight.csv')
dpw32_n09_reweight = pd.read_csv('logs/test_dp_w32_n09_reweight.csv')
dpw32_n11_reweight = pd.read_csv('logs/test_dp_w32_n11_reweight.csv')
dpw32_n12_reweight = pd.read_csv('logs/test_dp_w32_n12_reweight.csv')
dpw32_n13_reweight = pd.read_csv('logs/test_dp_w32_n13_reweight.csv')

# %%
dpw32_n07_worst_group_reweight = np.mean(np.array(dpw32_n07_reweight['avg_loss_group:3'])[40:])
dpw32_n08_worst_group_reweight = np.mean(np.array(dpw32_n08_reweight['avg_loss_group:3'])[40:])
dpw32_n09_worst_group_reweight = np.mean(np.array(dpw32_n09_reweight['avg_loss_group:3'])[40:])
dpw32_n11_worst_group_reweight = np.mean(np.array(dpw32_n11_reweight['avg_loss_group:3'])[40:])
dpw32_n12_worst_group_reweight = np.mean(np.array(dpw32_n12_reweight['avg_loss_group:3'])[40:])
dpw32_n13_worst_group_reweight = np.mean(np.array(dpw32_n13_reweight['avg_loss_group:3'])[40:])

# %%
test_errors = np.array([dpw32_n07_reweight['avg_actual_loss'][49], dpw32_n08_reweight['avg_actual_loss'][49], dpw32_n09_reweight['avg_actual_loss'][49], dpw32_n11_reweight['avg_actual_loss'][49], dpw32_n12_reweight['avg_actual_loss'][49], dpw32_n13_reweight['avg_actual_loss'][49]])
worst_group_errors = np.array([dpw32_n07_worst_group_reweight, dpw32_n08_worst_group_reweight, dpw32_n09_worst_group_reweight, dpw32_n11_worst_group_reweight, dpw32_n12_worst_group_reweight, dpw32_n13_worst_group_reweight])
plt.plot(np.array([0.7, 0.8, 0.9, 1.1, 1.2, 1.3]), test_errors, marker='o', label='average test')
plt.plot(np.array([0.7, 0.8, 0.9, 1.1, 1.2, 1.3]), worst_group_errors, marker='o', label='worst-group test')
plt.title("CelebA with 0.0001 Weight Decay, Varying DP noise, reweighting")
plt.xlabel("DP-Noise_mult")
plt.ylabel("Error")
plt.legend()

# %%
dpw32_n05_reweight = pd.read_csv('logs/test_dp_w32_n05_reweight.csv')
dpw32_n08_reweight = pd.read_csv('logs/test_dp_w32_n08_reweight.csv')
dpw32_n11_reweight = pd.read_csv('logs/test_dp_w32_n11_reweight.csv')
dpw32_n14_reweight = pd.read_csv('logs/test_dp_w32_n14_reweight.csv')
dpw32_n17_reweight = pd.read_csv('logs/test_dp_w32_n17_reweight.csv')
dpw32_n20_reweight = pd.read_csv('logs/test_dp_w32_n20_reweight.csv')
dpw32_n23_reweight = pd.read_csv('logs/test_dp_w32_n23_reweight.csv')
dpw32_n26_reweight = pd.read_csv('logs/test_dp_w32_n26_reweight.csv')
dpw32_n29_reweight = pd.read_csv('logs/test_dp_w32_n29_reweight.csv')
dpw32_n32_reweight = pd.read_csv('logs/test_dp_w32_n32_reweight.csv')

# %%
dpw32_n05_worst_group_reweight = np.mean(np.array(dpw32_n05_reweight['avg_loss_group:3'])[40:])
dpw32_n08_worst_group_reweight = np.mean(np.array(dpw32_n08_reweight['avg_loss_group:3'])[40:])
dpw32_n11_worst_group_reweight = np.mean(np.array(dpw32_n11_reweight['avg_loss_group:3'])[40:])
dpw32_n14_worst_group_reweight = np.mean(np.array(dpw32_n14_reweight['avg_loss_group:3'])[40:])
dpw32_n17_worst_group_reweight = np.mean(np.array(dpw32_n17_reweight['avg_loss_group:3'])[40:])
dpw32_n20_worst_group_reweight = np.mean(np.array(dpw32_n20_reweight['avg_loss_group:3'])[40:])
dpw32_n23_worst_group_reweight = np.mean(np.array(dpw32_n23_reweight['avg_loss_group:3'])[40:])
dpw32_n26_worst_group_reweight = np.mean(np.array(dpw32_n26_reweight['avg_loss_group:3'])[40:])
dpw32_n29_worst_group_reweight = np.mean(np.array(dpw32_n29_reweight['avg_loss_group:3'])[40:])
dpw32_n32_worst_group_reweight = np.mean(np.array(dpw32_n32_reweight['avg_loss_group:3'])[40:])

# %%
test_errors = np.array([dpw32_n05_reweight['avg_actual_loss'][49], dpw32_n08_reweight['avg_actual_loss'][49], dpw32_n11_reweight['avg_actual_loss'][49], dpw32_n14_reweight['avg_actual_loss'][49], dpw32_n17_reweight['avg_actual_loss'][49], dpw32_n20_reweight['avg_actual_loss'][49], dpw32_n23_reweight['avg_actual_loss'][49],dpw32_n26_reweight['avg_actual_loss'][49],dpw32_n29_reweight['avg_actual_loss'][49],dpw32_n32_reweight['avg_actual_loss'][49]])
worst_group_errors = np.array([dpw32_n05_worst_group_reweight, dpw32_n08_worst_group_reweight, dpw32_n11_worst_group_reweight, dpw32_n14_worst_group_reweight, dpw32_n17_worst_group_reweight, dpw32_n20_worst_group_reweight, dpw32_n23_worst_group_reweight, dpw32_n26_worst_group_reweight, dpw32_n29_worst_group_reweight, dpw32_n32_worst_group_reweight])
plt.plot(np.array([0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), test_errors, marker='o', label='average test')
plt.plot(np.array([0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), worst_group_errors, marker='o', label='worst-group test')
plt.title("Resnet10 Width 32 0.0001 Weight Decay, Varying DP noise, reweighting")
plt.xlabel("DP-Noise_mult")
plt.ylabel("Error")
plt.legend()

# %%
dpw1_n05_reweight = pd.read_csv('logs/test_dp_w1_n05_reweight.csv')
dpw1_n08_reweight = pd.read_csv('logs/test_dp_w1_n08_reweight.csv')
dpw1_n11_reweight = pd.read_csv('logs/test_dp_w1_n11_reweight.csv')
dpw1_n14_reweight = pd.read_csv('logs/test_dp_w1_n14_reweight.csv')
dpw1_n17_reweight = pd.read_csv('logs/test_dp_w1_n17_reweight.csv')
dpw1_n20_reweight = pd.read_csv('logs/test_dp_w1_n20_reweight.csv')
dpw1_n23_reweight = pd.read_csv('logs/test_dp_w1_n23_reweight.csv')
dpw1_n26_reweight = pd.read_csv('logs/test_dp_w1_n26_reweight.csv')
dpw1_n29_reweight = pd.read_csv('logs/test_dp_w1_n29_reweight.csv')
dpw1_n32_reweight = pd.read_csv('logs/test_dp_w1_n32_reweight.csv')

# %%
dpw1_n05_worst_group_reweight = np.mean(np.array(dpw1_n05_reweight['avg_loss_group:3'])[40:])
dpw1_n08_worst_group_reweight = np.mean(np.array(dpw1_n08_reweight['avg_loss_group:3'])[40:])
dpw1_n11_worst_group_reweight = np.mean(np.array(dpw1_n11_reweight['avg_loss_group:3'])[40:])
dpw1_n14_worst_group_reweight = np.mean(np.array(dpw1_n14_reweight['avg_loss_group:3'])[40:])
dpw1_n17_worst_group_reweight = np.mean(np.array(dpw1_n17_reweight['avg_loss_group:3'])[40:])
dpw1_n20_worst_group_reweight = np.mean(np.array(dpw1_n20_reweight['avg_loss_group:3'])[40:])
dpw1_n23_worst_group_reweight = np.mean(np.array(dpw1_n23_reweight['avg_loss_group:3'])[40:])
dpw1_n26_worst_group_reweight = np.mean(np.array(dpw1_n26_reweight['avg_loss_group:3'])[40:])
dpw1_n29_worst_group_reweight = np.mean(np.array(dpw1_n29_reweight['avg_loss_group:3'])[40:])
dpw1_n32_worst_group_reweight = np.mean(np.array(dpw1_n32_reweight['avg_loss_group:3'])[40:])

# %%
test_errors = np.array([dpw1_n05_reweight['avg_actual_loss'][49], dpw1_n08_reweight['avg_actual_loss'][49], dpw1_n11_reweight['avg_actual_loss'][49], dpw1_n14_reweight['avg_actual_loss'][49], dpw1_n17_reweight['avg_actual_loss'][49], dpw1_n20_reweight['avg_actual_loss'][49], dpw1_n23_reweight['avg_actual_loss'][49],dpw1_n26_reweight['avg_actual_loss'][49],dpw1_n29_reweight['avg_actual_loss'][49],dpw1_n32_reweight['avg_actual_loss'][49]])
worst_group_errors = np.array([dpw1_n05_worst_group_reweight, dpw1_n08_worst_group_reweight, dpw1_n11_worst_group_reweight, dpw1_n14_worst_group_reweight, dpw1_n17_worst_group_reweight, dpw1_n20_worst_group_reweight, dpw1_n23_worst_group_reweight, dpw1_n26_worst_group_reweight, dpw1_n29_worst_group_reweight, dpw1_n32_worst_group_reweight])
plt.plot(np.array([0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), test_errors, marker='o', label='average test')
plt.plot(np.array([0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), worst_group_errors, marker='o', label='worst-group test')
plt.title("Resnet10 Width 1 0.0001 Weight Decay, Varying DP noise, reweighting")
plt.xlabel("DP-Noise_mult")
plt.ylabel("Error")
plt.legend()

# %%
dpw4_n05_reweight = pd.read_csv('logs/test_dp_w4_n05_reweight.csv')
dpw4_n08_reweight = pd.read_csv('logs/test_dp_w4_n08_reweight.csv')
dpw4_n11_reweight = pd.read_csv('logs/test_dp_w4_n11_reweight.csv')
dpw4_n14_reweight = pd.read_csv('logs/test_dp_w4_n14_reweight.csv')
dpw4_n17_reweight = pd.read_csv('logs/test_dp_w4_n17_reweight.csv')
dpw4_n20_reweight = pd.read_csv('logs/test_dp_w4_n20_reweight.csv')
dpw4_n23_reweight = pd.read_csv('logs/test_dp_w4_n23_reweight.csv')
dpw4_n26_reweight = pd.read_csv('logs/test_dp_w4_n26_reweight.csv')
dpw4_n29_reweight = pd.read_csv('logs/test_dp_w4_n29_reweight.csv')
dpw4_n32_reweight = pd.read_csv('logs/test_dp_w4_n32_reweight.csv')

# %%
dpw4_n05_worst_group_reweight = np.mean(np.array(dpw4_n05_reweight['avg_loss_group:3'])[40:])
dpw4_n08_worst_group_reweight = np.mean(np.array(dpw4_n08_reweight['avg_loss_group:3'])[40:])
dpw4_n11_worst_group_reweight = np.mean(np.array(dpw4_n11_reweight['avg_loss_group:3'])[40:])
dpw4_n14_worst_group_reweight = np.mean(np.array(dpw4_n14_reweight['avg_loss_group:3'])[40:])
dpw4_n17_worst_group_reweight = np.mean(np.array(dpw4_n17_reweight['avg_loss_group:3'])[40:])
dpw4_n20_worst_group_reweight = np.mean(np.array(dpw4_n20_reweight['avg_loss_group:3'])[40:])
dpw4_n23_worst_group_reweight = np.mean(np.array(dpw4_n23_reweight['avg_loss_group:3'])[40:])
dpw4_n26_worst_group_reweight = np.mean(np.array(dpw4_n26_reweight['avg_loss_group:3'])[40:])
dpw4_n29_worst_group_reweight = np.mean(np.array(dpw4_n29_reweight['avg_loss_group:3'])[40:])
dpw4_n32_worst_group_reweight = np.mean(np.array(dpw4_n32_reweight['avg_loss_group:3'])[40:])

# %%
test_errors = np.array([dpw4_n05_reweight['avg_actual_loss'][49], dpw4_n08_reweight['avg_actual_loss'][49], dpw4_n11_reweight['avg_actual_loss'][49], dpw4_n14_reweight['avg_actual_loss'][49], dpw4_n17_reweight['avg_actual_loss'][49], dpw4_n20_reweight['avg_actual_loss'][49], dpw4_n23_reweight['avg_actual_loss'][49],dpw4_n26_reweight['avg_actual_loss'][49],dpw4_n29_reweight['avg_actual_loss'][49],dpw4_n32_reweight['avg_actual_loss'][49]])
worst_group_errors = np.array([dpw4_n05_worst_group_reweight, dpw4_n08_worst_group_reweight, dpw4_n11_worst_group_reweight, dpw4_n14_worst_group_reweight, dpw4_n17_worst_group_reweight, dpw4_n20_worst_group_reweight, dpw4_n23_worst_group_reweight, dpw4_n26_worst_group_reweight, dpw4_n29_worst_group_reweight, dpw4_n32_worst_group_reweight])
plt.plot(np.array([0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), test_errors, marker='o', label='average test')
plt.plot(np.array([0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), worst_group_errors, marker='o', label='worst-group test')
plt.title("Resnet10 Width 4 0.0001 Weight Decay, Varying DP noise, reweighting")
plt.xlabel("DP-Noise_mult")
plt.ylabel("Error")
plt.legend()

# %%
dpw16_n05_reweight = pd.read_csv('logs/test_dp_w16_n05_reweight.csv')
dpw16_n08_reweight = pd.read_csv('logs/test_dp_w16_n08_reweight.csv')
dpw16_n11_reweight = pd.read_csv('logs/test_dp_w16_n11_reweight.csv')
dpw16_n14_reweight = pd.read_csv('logs/test_dp_w16_n14_reweight.csv')
dpw16_n17_reweight = pd.read_csv('logs/test_dp_w16_n17_reweight.csv')
dpw16_n20_reweight = pd.read_csv('logs/test_dp_w16_n20_reweight.csv')
dpw16_n23_reweight = pd.read_csv('logs/test_dp_w16_n23_reweight.csv')
dpw16_n26_reweight = pd.read_csv('logs/test_dp_w16_n26_reweight.csv')
dpw16_n29_reweight = pd.read_csv('logs/test_dp_w16_n29_reweight.csv')
dpw16_n32_reweight = pd.read_csv('logs/test_dp_w16_n32_reweight.csv')

# %%
dpw16_n05_worst_group_reweight = np.mean(np.array(dpw16_n05_reweight['avg_loss_group:3'])[40:])
dpw16_n08_worst_group_reweight = np.mean(np.array(dpw16_n08_reweight['avg_loss_group:3'])[40:])
dpw16_n11_worst_group_reweight = np.mean(np.array(dpw16_n11_reweight['avg_loss_group:3'])[40:])
dpw16_n14_worst_group_reweight = np.mean(np.array(dpw16_n14_reweight['avg_loss_group:3'])[40:])
dpw16_n17_worst_group_reweight = np.mean(np.array(dpw16_n17_reweight['avg_loss_group:3'])[40:])
dpw16_n20_worst_group_reweight = np.mean(np.array(dpw16_n20_reweight['avg_loss_group:3'])[40:])
dpw16_n23_worst_group_reweight = np.mean(np.array(dpw16_n23_reweight['avg_loss_group:3'])[40:])
dpw16_n26_worst_group_reweight = np.mean(np.array(dpw16_n26_reweight['avg_loss_group:3'])[40:])
dpw16_n29_worst_group_reweight = np.mean(np.array(dpw16_n29_reweight['avg_loss_group:3'])[40:])
dpw16_n32_worst_group_reweight = np.mean(np.array(dpw16_n32_reweight['avg_loss_group:3'])[40:])

# %%
test_errors = np.array([dpw16_n05_reweight['avg_actual_loss'][49], dpw16_n08_reweight['avg_actual_loss'][49], dpw16_n11_reweight['avg_actual_loss'][49], dpw16_n14_reweight['avg_actual_loss'][49], dpw16_n17_reweight['avg_actual_loss'][49], dpw16_n20_reweight['avg_actual_loss'][49], dpw16_n23_reweight['avg_actual_loss'][49],dpw16_n26_reweight['avg_actual_loss'][49],dpw16_n29_reweight['avg_actual_loss'][49],dpw16_n32_reweight['avg_actual_loss'][49]])
worst_group_errors = np.array([dpw16_n05_worst_group_reweight, dpw16_n08_worst_group_reweight, dpw16_n11_worst_group_reweight, dpw16_n14_worst_group_reweight, dpw16_n17_worst_group_reweight, dpw16_n20_worst_group_reweight, dpw16_n23_worst_group_reweight, dpw16_n26_worst_group_reweight, dpw16_n29_worst_group_reweight, dpw16_n32_worst_group_reweight])
plt.plot(np.array([0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), test_errors, marker='o', label='average test')
plt.plot(np.array([0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), worst_group_errors, marker='o', label='worst-group test')
plt.title("Resnet10 Width 16 0.0001 Weight Decay, Varying DP noise, reweighting")
plt.xlabel("DP-Noise_mult")
plt.ylabel("Error")
plt.legend()

# %%
dpw64_n05_reweight = pd.read_csv('logs/test_dp_w64_n05_reweight.csv')
dpw64_n08_reweight = pd.read_csv('logs/test_dp_w64_n08_reweight.csv')
dpw64_n11_reweight = pd.read_csv('logs/test_dp_w64_n11_reweight.csv')
dpw64_n14_reweight = pd.read_csv('logs/test_dp_w64_n14_reweight.csv')
dpw64_n17_reweight = pd.read_csv('logs/test_dp_w64_n17_reweight.csv')
dpw64_n20_reweight = pd.read_csv('logs/test_dp_w64_n20_reweight.csv')
dpw64_n23_reweight = pd.read_csv('logs/test_dp_w64_n23_reweight.csv')
dpw64_n26_reweight = pd.read_csv('logs/test_dp_w64_n26_reweight.csv')
dpw64_n29_reweight = pd.read_csv('logs/test_dp_w64_n29_reweight.csv')
dpw64_n32_reweight = pd.read_csv('logs/test_dp_w64_n32_reweight.csv')

# %%
dpw64_n05_worst_group_reweight = np.mean(np.array(dpw64_n05_reweight['avg_loss_group:3'])[40:])
dpw64_n08_worst_group_reweight = np.mean(np.array(dpw64_n08_reweight['avg_loss_group:3'])[40:])
dpw64_n11_worst_group_reweight = np.mean(np.array(dpw64_n11_reweight['avg_loss_group:3'])[40:])
dpw64_n14_worst_group_reweight = np.mean(np.array(dpw64_n14_reweight['avg_loss_group:3'])[40:])
dpw64_n17_worst_group_reweight = np.mean(np.array(dpw64_n17_reweight['avg_loss_group:3'])[40:])
dpw64_n20_worst_group_reweight = np.mean(np.array(dpw64_n20_reweight['avg_loss_group:3'])[40:])
dpw64_n23_worst_group_reweight = np.mean(np.array(dpw64_n23_reweight['avg_loss_group:3'])[40:])
dpw64_n26_worst_group_reweight = np.mean(np.array(dpw64_n26_reweight['avg_loss_group:3'])[40:])
dpw64_n29_worst_group_reweight = np.mean(np.array(dpw64_n29_reweight['avg_loss_group:3'])[40:])
dpw64_n32_worst_group_reweight = np.mean(np.array(dpw64_n32_reweight['avg_loss_group:3'])[40:])

# %%
test_errors = np.array([dpw64_n05_reweight['avg_actual_loss'][49], dpw64_n08_reweight['avg_actual_loss'][49], dpw64_n11_reweight['avg_actual_loss'][49], dpw64_n14_reweight['avg_actual_loss'][49], dpw64_n17_reweight['avg_actual_loss'][49], dpw64_n20_reweight['avg_actual_loss'][49], dpw64_n23_reweight['avg_actual_loss'][49],dpw64_n26_reweight['avg_actual_loss'][49],dpw64_n29_reweight['avg_actual_loss'][49],dpw64_n32_reweight['avg_actual_loss'][49]])
worst_group_errors = np.array([dpw64_n05_worst_group_reweight, dpw64_n08_worst_group_reweight, dpw64_n11_worst_group_reweight, dpw64_n14_worst_group_reweight, dpw64_n17_worst_group_reweight, dpw64_n20_worst_group_reweight, dpw64_n23_worst_group_reweight, dpw64_n26_worst_group_reweight, dpw64_n29_worst_group_reweight, dpw64_n32_worst_group_reweight])
plt.plot(np.array([0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), test_errors, marker='o', label='average test')
plt.plot(np.array([0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), worst_group_errors, marker='o', label='worst-group test')
plt.title("Resnet10 Width 64 0.0001 Weight Decay, Varying DP noise, reweighting")
plt.xlabel("DP-Noise_mult")
plt.ylabel("Error")
plt.legend()

# %%
dpw96_n05_reweight = pd.read_csv('logs/test_dp_w96_n05_reweight.csv')
dpw96_n08_reweight = pd.read_csv('logs/test_dp_w96_n08_reweight.csv')
dpw96_n11_reweight = pd.read_csv('logs/test_dp_w96_n11_reweight.csv')
dpw96_n14_reweight = pd.read_csv('logs/test_dp_w96_n14_reweight.csv')
dpw96_n17_reweight = pd.read_csv('logs/test_dp_w96_n17_reweight.csv')
dpw96_n20_reweight = pd.read_csv('logs/test_dp_w96_n20_reweight.csv')
dpw96_n23_reweight = pd.read_csv('logs/test_dp_w96_n23_reweight.csv')
dpw96_n26_reweight = pd.read_csv('logs/test_dp_w96_n26_reweight.csv')
dpw96_n29_reweight = pd.read_csv('logs/test_dp_w96_n29_reweight.csv')
dpw96_n32_reweight = pd.read_csv('logs/test_dp_w96_n32_reweight.csv')

# %%
dpw96_n05_worst_group_reweight = np.mean(np.array(dpw96_n05_reweight['avg_loss_group:3'])[40:])
dpw96_n08_worst_group_reweight = np.mean(np.array(dpw96_n08_reweight['avg_loss_group:3'])[40:])
dpw96_n11_worst_group_reweight = np.mean(np.array(dpw96_n11_reweight['avg_loss_group:3'])[40:])
dpw96_n14_worst_group_reweight = np.mean(np.array(dpw96_n14_reweight['avg_loss_group:3'])[40:])
dpw96_n17_worst_group_reweight = np.mean(np.array(dpw96_n17_reweight['avg_loss_group:3'])[40:])
dpw96_n20_worst_group_reweight = np.mean(np.array(dpw96_n20_reweight['avg_loss_group:3'])[40:])
dpw96_n23_worst_group_reweight = np.mean(np.array(dpw96_n23_reweight['avg_loss_group:3'])[40:])
dpw96_n26_worst_group_reweight = np.mean(np.array(dpw96_n26_reweight['avg_loss_group:3'])[40:])
dpw96_n29_worst_group_reweight = np.mean(np.array(dpw96_n29_reweight['avg_loss_group:3'])[40:])
dpw96_n32_worst_group_reweight = np.mean(np.array(dpw96_n32_reweight['avg_loss_group:3'])[40:])

# %%
test_errors = np.array([dpw96_n05_reweight['avg_actual_loss'][49], dpw96_n08_reweight['avg_actual_loss'][49], dpw96_n11_reweight['avg_actual_loss'][49], dpw96_n14_reweight['avg_actual_loss'][49], dpw96_n17_reweight['avg_actual_loss'][49], dpw96_n20_reweight['avg_actual_loss'][49], dpw96_n23_reweight['avg_actual_loss'][49], dpw96_n26_reweight['avg_actual_loss'][49], dpw96_n29_reweight['avg_actual_loss'][49], dpw96_n32_reweight['avg_actual_loss'][49]])
worst_group_errors = np.array([dpw96_n05_worst_group_reweight, dpw96_n08_worst_group_reweight, dpw96_n11_worst_group_reweight, dpw96_n14_worst_group_reweight, dpw96_n17_worst_group_reweight, dpw96_n20_worst_group_reweight, dpw96_n23_worst_group_reweight, dpw96_n26_worst_group_reweight, dpw96_n29_worst_group_reweight, dpw96_n32_worst_group_reweight])
plt.plot(np.array([0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), test_errors, marker='o', label='average test')
plt.plot(np.array([0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), worst_group_errors, marker='o', label='worst-group test')
plt.title("Resnet10 Width 96 0.0001 Weight Decay, Varying DP noise, reweighting")
plt.xlabel("DP-Noise_mult")
plt.ylabel("Error")
plt.legend()

# %% [markdown]
# ## Random seeds for width 16

# %%
dpw16_n03_reweight_s1 = pd.read_csv('logs/test_dp_w16_n03_reweight_seed1.csv')
dpw16_n04_reweight_s1 = pd.read_csv('logs/test_dp_w16_n04_reweight_seed1.csv')
dpw16_n05_reweight_s1 = pd.read_csv('logs/test_dp_w16_n05_reweight_seed1.csv')
dpw16_n08_reweight_s1 = pd.read_csv('logs/test_dp_w16_n08_reweight_seed1.csv')
dpw16_n11_reweight_s1 = pd.read_csv('logs/test_dp_w16_n11_reweight_seed1.csv')
dpw16_n14_reweight_s1 = pd.read_csv('logs/test_dp_w16_n14_reweight_seed1.csv')
dpw16_n17_reweight_s1 = pd.read_csv('logs/test_dp_w16_n17_reweight_seed1.csv')
dpw16_n20_reweight_s1 = pd.read_csv('logs/test_dp_w16_n20_reweight_seed1.csv')
dpw16_n23_reweight_s1 = pd.read_csv('logs/test_dp_w16_n23_reweight_seed1.csv')
dpw16_n26_reweight_s1 = pd.read_csv('logs/test_dp_w16_n26_reweight_seed1.csv')
dpw16_n29_reweight_s1 = pd.read_csv('logs/test_dp_w16_n29_reweight_seed1.csv')
dpw16_n32_reweight_s1 = pd.read_csv('logs/test_dp_w16_n32_reweight_seed1.csv')

# %%
dpw16_n03_worst_group_reweight_s1 = np.mean(np.array(dpw16_n03_reweight_s1['avg_loss_group:3'])[40:])
dpw16_n04_worst_group_reweight_s1 = np.mean(np.array(dpw16_n04_reweight_s1['avg_loss_group:3'])[40:])
dpw16_n05_worst_group_reweight_s1 = np.mean(np.array(dpw16_n05_reweight_s1['avg_loss_group:3'])[40:])
dpw16_n08_worst_group_reweight_s1 = np.mean(np.array(dpw16_n08_reweight_s1['avg_loss_group:3'])[40:])
dpw16_n11_worst_group_reweight_s1 = np.mean(np.array(dpw16_n11_reweight_s1['avg_loss_group:3'])[40:])
dpw16_n14_worst_group_reweight_s1 = np.mean(np.array(dpw16_n14_reweight_s1['avg_loss_group:3'])[40:])
dpw16_n17_worst_group_reweight_s1 = np.mean(np.array(dpw16_n17_reweight_s1['avg_loss_group:3'])[40:])
dpw16_n20_worst_group_reweight_s1 = np.mean(np.array(dpw16_n20_reweight_s1['avg_loss_group:3'])[40:])
dpw16_n23_worst_group_reweight_s1 = np.mean(np.array(dpw16_n23_reweight_s1['avg_loss_group:3'])[40:])
dpw16_n26_worst_group_reweight_s1 = np.mean(np.array(dpw16_n26_reweight_s1['avg_loss_group:3'])[40:])
dpw16_n29_worst_group_reweight_s1 = np.mean(np.array(dpw16_n29_reweight_s1['avg_loss_group:3'])[40:])
dpw16_n32_worst_group_reweight_s1 = np.mean(np.array(dpw16_n32_reweight_s1['avg_loss_group:3'])[40:])

dpw16_n03_reweight_last10_s1 = np.mean(np.array(dpw16_n03_reweight_s1['avg_actual_loss'])[45:])
dpw16_n04_reweight_last10_s1 = np.mean(np.array(dpw16_n04_reweight_s1['avg_actual_loss'])[45:])
dpw16_n05_reweight_last10_s1 = np.mean(np.array(dpw16_n05_reweight_s1['avg_actual_loss'])[45:])
dpw16_n08_reweight_last10_s1 = np.mean(np.array(dpw16_n08_reweight_s1['avg_actual_loss'])[45:])
dpw16_n11_reweight_last10_s1 = np.mean(np.array(dpw16_n11_reweight_s1['avg_actual_loss'])[45:])
dpw16_n14_reweight_last10_s1 = np.mean(np.array(dpw16_n14_reweight_s1['avg_actual_loss'])[45:])
dpw16_n17_reweight_last10_s1 = np.mean(np.array(dpw16_n17_reweight_s1['avg_actual_loss'])[45:])
dpw16_n20_reweight_last10_s1 = np.mean(np.array(dpw16_n20_reweight_s1['avg_actual_loss'])[45:])
dpw16_n23_reweight_last10_s1 = np.mean(np.array(dpw16_n23_reweight_s1['avg_actual_loss'])[45:])
dpw16_n26_reweight_last10_s1 = np.mean(np.array(dpw16_n26_reweight_s1['avg_actual_loss'])[45:])
dpw16_n29_reweight_last10_s1 = np.mean(np.array(dpw16_n29_reweight_s1['avg_actual_loss'])[45:])
dpw16_n32_reweight_last10_s1 = np.mean(np.array(dpw16_n32_reweight_s1['avg_actual_loss'])[45:])

# %%
test_errors_s1_smoothed = np.array([dpw16_n03_reweight_last10_s1, dpw16_n04_reweight_last10_s1, dpw16_n05_reweight_last10_s1, dpw16_n08_reweight_last10_s1, dpw16_n11_reweight_last10_s1, dpw16_n14_reweight_last10_s1, dpw16_n17_reweight_last10_s1, dpw16_n20_reweight_last10_s1, dpw16_n23_reweight_last10_s1, dpw16_n26_reweight_last10_s1, dpw16_n29_reweight_last10_s1, dpw16_n32_reweight_last10_s1])
worst_group_errors_s1_smoothed = np.array([dpw16_n03_worst_group_reweight_s1, dpw16_n04_worst_group_reweight_s1, dpw16_n05_worst_group_reweight_s1, dpw16_n08_worst_group_reweight_s1, dpw16_n11_worst_group_reweight_s1, dpw16_n14_worst_group_reweight_s1, dpw16_n17_worst_group_reweight_s1, dpw16_n20_worst_group_reweight_s1, dpw16_n23_worst_group_reweight_s1, dpw16_n26_worst_group_reweight_s1, dpw16_n29_worst_group_reweight_s1, dpw16_n32_worst_group_reweight_s1])
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), test_errors_s1_smoothed, marker='o', label='average test')
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), worst_group_errors_s1_smoothed, marker='o', label='worst-group test')
plt.title("Resnet10 Width 16 0.0001 Weight Decay, Varying DP noise, reweighting seed 1 smoothed")
plt.xlabel("DP-Noise_mult")
plt.ylabel("Error")
plt.legend()

# %%
test_errors_s1 = np.array([dpw16_n03_reweight_s1['avg_actual_loss'][49], dpw16_n04_reweight_s1['avg_actual_loss'][49], dpw16_n05_reweight_s1['avg_actual_loss'][49], dpw16_n08_reweight_s1['avg_actual_loss'][49], dpw16_n11_reweight_s1['avg_actual_loss'][49], dpw16_n14_reweight_s1['avg_actual_loss'][49], dpw16_n17_reweight_s1['avg_actual_loss'][49], dpw16_n20_reweight_s1['avg_actual_loss'][49], dpw16_n23_reweight_s1['avg_actual_loss'][49], dpw16_n26_reweight_s1['avg_actual_loss'][49], dpw16_n29_reweight_s1['avg_actual_loss'][49], dpw16_n32_reweight_s1['avg_actual_loss'][49]])
worst_group_errors_s1 = np.array([dpw16_n03_worst_group_reweight_s1, dpw16_n04_worst_group_reweight_s1, dpw16_n05_worst_group_reweight_s1, dpw16_n08_worst_group_reweight_s1, dpw16_n11_worst_group_reweight_s1, dpw16_n14_worst_group_reweight_s1, dpw16_n17_worst_group_reweight_s1, dpw16_n20_worst_group_reweight_s1, dpw16_n23_worst_group_reweight_s1, dpw16_n26_worst_group_reweight_s1, dpw16_n29_worst_group_reweight_s1, dpw16_n32_worst_group_reweight_s1])
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), test_errors_s1, marker='o', label='average test')
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), worst_group_errors_s1, marker='o', label='worst-group test')
plt.title("Resnet10 Width 16 0.0001 Weight Decay, Varying DP noise, reweighting seed 1")
plt.xlabel("DP-Noise_mult")
plt.ylabel("Error")
plt.legend()

# %%
dpw16_n03_reweight_s2 = pd.read_csv('logs/test_dp_w16_n03_reweight_seed2.csv')
dpw16_n04_reweight_s2 = pd.read_csv('logs/test_dp_w16_n04_reweight_seed2.csv')
dpw16_n05_reweight_s2 = pd.read_csv('logs/test_dp_w16_n05_reweight_seed2.csv')
dpw16_n08_reweight_s2 = pd.read_csv('logs/test_dp_w16_n08_reweight_seed2.csv')
dpw16_n11_reweight_s2 = pd.read_csv('logs/test_dp_w16_n11_reweight_seed2.csv')
dpw16_n14_reweight_s2 = pd.read_csv('logs/test_dp_w16_n14_reweight_seed2.csv')
dpw16_n17_reweight_s2 = pd.read_csv('logs/test_dp_w16_n17_reweight_seed2.csv')
dpw16_n20_reweight_s2 = pd.read_csv('logs/test_dp_w16_n20_reweight_seed2.csv')
dpw16_n23_reweight_s2 = pd.read_csv('logs/test_dp_w16_n23_reweight_seed2.csv')
dpw16_n26_reweight_s2 = pd.read_csv('logs/test_dp_w16_n26_reweight_seed2.csv')
dpw16_n29_reweight_s2 = pd.read_csv('logs/test_dp_w16_n29_reweight_seed2.csv')
dpw16_n32_reweight_s2 = pd.read_csv('logs/test_dp_w16_n32_reweight_seed2.csv')

# %%
dpw16_n03_worst_group_reweight_s2 = np.mean(np.array(dpw16_n03_reweight_s2['avg_loss_group:3'])[40:])
dpw16_n04_worst_group_reweight_s2 = np.mean(np.array(dpw16_n04_reweight_s2['avg_loss_group:3'])[40:])
dpw16_n05_worst_group_reweight_s2 = np.mean(np.array(dpw16_n05_reweight_s2['avg_loss_group:3'])[40:])
dpw16_n08_worst_group_reweight_s2 = np.mean(np.array(dpw16_n08_reweight_s2['avg_loss_group:3'])[40:])
dpw16_n11_worst_group_reweight_s2 = np.mean(np.array(dpw16_n11_reweight_s2['avg_loss_group:3'])[40:])
dpw16_n14_worst_group_reweight_s2 = np.mean(np.array(dpw16_n14_reweight_s2['avg_loss_group:3'])[40:])
dpw16_n17_worst_group_reweight_s2 = np.mean(np.array(dpw16_n17_reweight_s2['avg_loss_group:3'])[40:])
dpw16_n20_worst_group_reweight_s2 = np.mean(np.array(dpw16_n20_reweight_s2['avg_loss_group:3'])[40:])
dpw16_n23_worst_group_reweight_s2 = np.mean(np.array(dpw16_n23_reweight_s2['avg_loss_group:3'])[40:])
dpw16_n26_worst_group_reweight_s2 = np.mean(np.array(dpw16_n26_reweight_s2['avg_loss_group:3'])[40:])
dpw16_n29_worst_group_reweight_s2 = np.mean(np.array(dpw16_n29_reweight_s2['avg_loss_group:3'])[40:])
dpw16_n32_worst_group_reweight_s2 = np.mean(np.array(dpw16_n32_reweight_s2['avg_loss_group:3'])[40:])

dpw16_n03_reweight_last10_s2 = np.mean(np.array(dpw16_n03_reweight_s2['avg_actual_loss'])[45:])
dpw16_n04_reweight_last10_s2 = np.mean(np.array(dpw16_n04_reweight_s2['avg_actual_loss'])[45:])
dpw16_n05_reweight_last10_s2 = np.mean(np.array(dpw16_n05_reweight_s2['avg_actual_loss'])[45:])
dpw16_n08_reweight_last10_s2 = np.mean(np.array(dpw16_n08_reweight_s2['avg_actual_loss'])[45:])
dpw16_n11_reweight_last10_s2 = np.mean(np.array(dpw16_n11_reweight_s2['avg_actual_loss'])[45:])
dpw16_n14_reweight_last10_s2 = np.mean(np.array(dpw16_n14_reweight_s2['avg_actual_loss'])[45:])
dpw16_n17_reweight_last10_s2 = np.mean(np.array(dpw16_n17_reweight_s2['avg_actual_loss'])[45:])
dpw16_n20_reweight_last10_s2 = np.mean(np.array(dpw16_n20_reweight_s2['avg_actual_loss'])[45:])
dpw16_n23_reweight_last10_s2 = np.mean(np.array(dpw16_n23_reweight_s2['avg_actual_loss'])[45:])
dpw16_n26_reweight_last10_s2 = np.mean(np.array(dpw16_n26_reweight_s2['avg_actual_loss'])[45:])
dpw16_n29_reweight_last10_s2 = np.mean(np.array(dpw16_n29_reweight_s2['avg_actual_loss'])[45:])
dpw16_n32_reweight_last10_s2 = np.mean(np.array(dpw16_n32_reweight_s2['avg_actual_loss'])[45:])

# %%
test_errors_s2_smoothed = np.array([dpw16_n03_reweight_last10_s2, dpw16_n04_reweight_last10_s2, dpw16_n05_reweight_last10_s2, dpw16_n08_reweight_last10_s2, dpw16_n11_reweight_last10_s2, dpw16_n14_reweight_last10_s2, dpw16_n17_reweight_last10_s2, dpw16_n20_reweight_last10_s2, dpw16_n23_reweight_last10_s2, dpw16_n26_reweight_last10_s2, dpw16_n29_reweight_last10_s2, dpw16_n32_reweight_last10_s2])
worst_group_errors_s2_smoothed = np.array([dpw16_n03_worst_group_reweight_s2, dpw16_n04_worst_group_reweight_s2, dpw16_n05_worst_group_reweight_s2, dpw16_n08_worst_group_reweight_s2, dpw16_n11_worst_group_reweight_s2, dpw16_n14_worst_group_reweight_s2, dpw16_n17_worst_group_reweight_s2, dpw16_n20_worst_group_reweight_s2, dpw16_n23_worst_group_reweight_s2, dpw16_n26_worst_group_reweight_s2, dpw16_n29_worst_group_reweight_s2, dpw16_n32_worst_group_reweight_s2])
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), test_errors_s2_smoothed, marker='o', label='average test')
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), worst_group_errors_s2_smoothed, marker='o', label='worst-group test')
plt.title("Resnet10 Width 16 0.0001 Weight Decay, Varying DP noise, reweighting seed 2 smoothed")
plt.xlabel("DP-Noise_mult")
plt.ylabel("Error")
plt.legend()

# %%
test_errors_s2 = np.array([dpw16_n03_reweight_s2['avg_actual_loss'][49], dpw16_n04_reweight_s2['avg_actual_loss'][49], dpw16_n05_reweight_s2['avg_actual_loss'][49], dpw16_n08_reweight_s2['avg_actual_loss'][49], dpw16_n11_reweight_s2['avg_actual_loss'][49], dpw16_n14_reweight_s2['avg_actual_loss'][49], dpw16_n17_reweight_s2['avg_actual_loss'][49], dpw16_n20_reweight_s2['avg_actual_loss'][49], dpw16_n23_reweight_s2['avg_actual_loss'][49], dpw16_n26_reweight_s2['avg_actual_loss'][49], dpw16_n29_reweight_s2['avg_actual_loss'][49], dpw16_n32_reweight_s2['avg_actual_loss'][49]])
worst_group_errors_s2 = np.array([dpw16_n03_worst_group_reweight_s2, dpw16_n04_worst_group_reweight_s2, dpw16_n05_worst_group_reweight_s2, dpw16_n08_worst_group_reweight_s2, dpw16_n11_worst_group_reweight_s2, dpw16_n14_worst_group_reweight_s2, dpw16_n17_worst_group_reweight_s2, dpw16_n20_worst_group_reweight_s2, dpw16_n23_worst_group_reweight_s2, dpw16_n26_worst_group_reweight_s2, dpw16_n29_worst_group_reweight_s2, dpw16_n32_worst_group_reweight_s2])
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), test_errors_s2, marker='o', label='average test')
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), worst_group_errors_s2, marker='o', label='worst-group test')
plt.title("Resnet10 Width 16 0.0001 Weight Decay, Varying DP noise, reweighting seed 2")
plt.xlabel("DP-Noise_mult")
plt.ylabel("Error")
plt.legend()

# %%
dpw16_n03_reweight_s3 = pd.read_csv('logs/test_dp_w16_n03_reweight_seed3.csv')
dpw16_n04_reweight_s3 = pd.read_csv('logs/test_dp_w16_n04_reweight_seed3.csv')
dpw16_n05_reweight_s3 = pd.read_csv('logs/test_dp_w16_n05_reweight_seed3.csv')
dpw16_n08_reweight_s3 = pd.read_csv('logs/test_dp_w16_n08_reweight_seed3.csv')
dpw16_n11_reweight_s3 = pd.read_csv('logs/test_dp_w16_n11_reweight_seed3.csv')
dpw16_n14_reweight_s3 = pd.read_csv('logs/test_dp_w16_n14_reweight_seed3.csv')
dpw16_n17_reweight_s3 = pd.read_csv('logs/test_dp_w16_n17_reweight_seed3.csv')
dpw16_n20_reweight_s3 = pd.read_csv('logs/test_dp_w16_n20_reweight_seed3.csv')
dpw16_n23_reweight_s3 = pd.read_csv('logs/test_dp_w16_n23_reweight_seed3.csv')
dpw16_n26_reweight_s3 = pd.read_csv('logs/test_dp_w16_n26_reweight_seed3.csv')
dpw16_n29_reweight_s3 = pd.read_csv('logs/test_dp_w16_n29_reweight_seed3.csv')
dpw16_n32_reweight_s3 = pd.read_csv('logs/test_dp_w16_n32_reweight_seed3.csv')

# %%
dpw16_n03_worst_group_reweight_s3 = np.mean(np.array(dpw16_n03_reweight_s3['avg_loss_group:3'])[40:])
dpw16_n04_worst_group_reweight_s3 = np.mean(np.array(dpw16_n04_reweight_s3['avg_loss_group:3'])[40:])
dpw16_n05_worst_group_reweight_s3 = np.mean(np.array(dpw16_n05_reweight_s3['avg_loss_group:3'])[40:])
dpw16_n08_worst_group_reweight_s3 = np.mean(np.array(dpw16_n08_reweight_s3['avg_loss_group:3'])[40:])
dpw16_n11_worst_group_reweight_s3 = np.mean(np.array(dpw16_n11_reweight_s3['avg_loss_group:3'])[40:50])
dpw16_n14_worst_group_reweight_s3 = np.mean(np.array(dpw16_n14_reweight_s3['avg_loss_group:3'])[40:])
dpw16_n17_worst_group_reweight_s3 = np.mean(np.array(dpw16_n17_reweight_s3['avg_loss_group:3'])[40:])
dpw16_n20_worst_group_reweight_s3 = np.mean(np.array(dpw16_n20_reweight_s3['avg_loss_group:3'])[40:])
dpw16_n23_worst_group_reweight_s3 = np.mean(np.array(dpw16_n23_reweight_s3['avg_loss_group:3'])[40:])
dpw16_n26_worst_group_reweight_s3 = np.mean(np.array(dpw16_n26_reweight_s3['avg_loss_group:3'])[40:])
dpw16_n29_worst_group_reweight_s3 = np.mean(np.array(dpw16_n29_reweight_s3['avg_loss_group:3'])[40:])
dpw16_n32_worst_group_reweight_s3 = np.mean(np.array(dpw16_n32_reweight_s3['avg_loss_group:3'])[40:])

dpw16_n03_reweight_last10_s3 = np.mean(np.array(dpw16_n03_reweight_s3['avg_actual_loss'])[45:])
dpw16_n04_reweight_last10_s3 = np.mean(np.array(dpw16_n04_reweight_s3['avg_actual_loss'])[45:])
dpw16_n05_reweight_last10_s3 = np.mean(np.array(dpw16_n05_reweight_s3['avg_actual_loss'])[45:])
dpw16_n08_reweight_last10_s3 = np.mean(np.array(dpw16_n08_reweight_s3['avg_actual_loss'])[45:])
dpw16_n11_reweight_last10_s3 = np.mean(np.array(dpw16_n11_reweight_s3['avg_actual_loss'])[45:50])
dpw16_n14_reweight_last10_s3 = np.mean(np.array(dpw16_n14_reweight_s3['avg_actual_loss'])[45:])
dpw16_n17_reweight_last10_s3 = np.mean(np.array(dpw16_n17_reweight_s3['avg_actual_loss'])[45:])
dpw16_n20_reweight_last10_s3 = np.mean(np.array(dpw16_n20_reweight_s3['avg_actual_loss'])[45:])
dpw16_n23_reweight_last10_s3 = np.mean(np.array(dpw16_n23_reweight_s3['avg_actual_loss'])[45:])
dpw16_n26_reweight_last10_s3 = np.mean(np.array(dpw16_n26_reweight_s3['avg_actual_loss'])[45:])
dpw16_n29_reweight_last10_s3 = np.mean(np.array(dpw16_n29_reweight_s3['avg_actual_loss'])[45:])
dpw16_n32_reweight_last10_s3 = np.mean(np.array(dpw16_n32_reweight_s3['avg_actual_loss'])[45:])

# %%
test_errors_s3_smoothed = np.array([dpw16_n03_reweight_last10_s3, dpw16_n04_reweight_last10_s3, dpw16_n05_reweight_last10_s3, dpw16_n08_reweight_last10_s3, dpw16_n11_reweight_last10_s3, dpw16_n14_reweight_last10_s3, dpw16_n17_reweight_last10_s3, dpw16_n20_reweight_last10_s3, dpw16_n23_reweight_last10_s3, dpw16_n26_reweight_last10_s3, dpw16_n29_reweight_last10_s3, dpw16_n32_reweight_last10_s3])
worst_group_errors_s3_smoothed = np.array([dpw16_n03_worst_group_reweight_s3, dpw16_n04_worst_group_reweight_s3, dpw16_n05_worst_group_reweight_s3, dpw16_n08_worst_group_reweight_s3, dpw16_n11_worst_group_reweight_s3, dpw16_n14_worst_group_reweight_s3, dpw16_n17_worst_group_reweight_s3, dpw16_n20_worst_group_reweight_s3, dpw16_n23_worst_group_reweight_s3, dpw16_n26_worst_group_reweight_s3, dpw16_n29_worst_group_reweight_s3, dpw16_n32_worst_group_reweight_s3])
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), test_errors_s3_smoothed, marker='o', label='average test')
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), worst_group_errors_s3_smoothed, marker='o', label='worst-group test')
plt.title("Resnet10 Width 16 0.0001 Weight Decay, Varying DP noise, reweighting seed 3 smoothed")
plt.xlabel("DP-Noise_mult")
plt.ylabel("Error")
plt.legend()

# %%
test_errors_s3 = np.array([dpw16_n03_reweight_s3['avg_actual_loss'][49], dpw16_n04_reweight_s3['avg_actual_loss'][49], dpw16_n05_reweight_s3['avg_actual_loss'][49], dpw16_n08_reweight_s3['avg_actual_loss'][49], dpw16_n11_reweight_s3['avg_actual_loss'][49], dpw16_n14_reweight_s3['avg_actual_loss'][49], dpw16_n17_reweight_s3['avg_actual_loss'][49], dpw16_n20_reweight_s3['avg_actual_loss'][49], dpw16_n23_reweight_s3['avg_actual_loss'][49], dpw16_n26_reweight_s3['avg_actual_loss'][49], dpw16_n29_reweight_s3['avg_actual_loss'][49], dpw16_n32_reweight_s3['avg_actual_loss'][49]])
worst_group_errors_s3 = np.array([dpw16_n03_worst_group_reweight_s3, dpw16_n04_worst_group_reweight_s3, dpw16_n05_worst_group_reweight_s3, dpw16_n08_worst_group_reweight_s3, dpw16_n11_worst_group_reweight_s3, dpw16_n14_worst_group_reweight_s3, dpw16_n17_worst_group_reweight_s3, dpw16_n20_worst_group_reweight_s3, dpw16_n23_worst_group_reweight_s3, dpw16_n26_worst_group_reweight_s3, dpw16_n29_worst_group_reweight_s3, dpw16_n32_worst_group_reweight_s3])
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), test_errors_s3, marker='o', label='average test')
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), worst_group_errors_s3, marker='o', label='worst-group test')
plt.title("Resnet10 Width 16 0.0001 Weight Decay, Varying DP noise, reweighting seed 3")
plt.xlabel("DP-Noise_mult")
plt.ylabel("Error")
plt.legend()

# %%
test_errors_smoothed_avg_16 = np.average([test_errors_s1_smoothed, test_errors_s2_smoothed, test_errors_s3_smoothed], axis=0)
worst_group_errors_smoothed_avg_16 = np.average([worst_group_errors_s1, worst_group_errors_s2, worst_group_errors_s3], axis=0)
noises = np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2])

test_errors_smoothed_avg_16_lower = np.min([test_errors_s1_smoothed, test_errors_s2_smoothed, test_errors_s3_smoothed], axis=0)
test_errors_smoothed_avg_16_upper = np.max([test_errors_s1_smoothed, test_errors_s2_smoothed, test_errors_s3_smoothed], axis=0)
worst_group_errors_smoothed_avg_16_lower = np.min([worst_group_errors_s1, worst_group_errors_s2, worst_group_errors_s3], axis=0)
worst_group_errors_smoothed_avg_16_upper = np.max([worst_group_errors_s1, worst_group_errors_s2, worst_group_errors_s3], axis=0)
plt.plot(noises, test_errors_smoothed_avg_16, marker='o', label='average test')
plt.plot(noises, worst_group_errors_smoothed_avg_16, marker='o', label='worst-group test')
plt.title("Width 16, 0.0001 Weight Decay, Varying DP noise, Reweighting, average of 3 seeds with smoothing")
plt.xlabel("DP-Noise_mult")
plt.ylabel("Error")
# ax = plt.subplots()
plt.fill_between(noises, test_errors_smoothed_avg_16_lower, test_errors_smoothed_avg_16_upper, alpha=0.2, color='tab:blue')
plt.fill_between(noises, worst_group_errors_smoothed_avg_16_lower, worst_group_errors_smoothed_avg_16_upper, alpha=0.2, color='tab:orange')

plt.legend()

# %%
test_errors_avg_16 = np.average([test_errors_s1, test_errors_s2, test_errors_s3], axis=0)
worst_group_errors_avg_16 = np.average([worst_group_errors_s1, worst_group_errors_s2, worst_group_errors_s3], axis=0)

test_errors_avg_16_lower = np.min([test_errors_s1, test_errors_s2, test_errors_s3], axis=0)
test_errors_avg_16_upper = np.max([test_errors_s1, test_errors_s2, test_errors_s3], axis=0)
worst_group_errors_avg_16_lower = np.min([worst_group_errors_s1, worst_group_errors_s2, worst_group_errors_s3], axis=0)
worst_group_errors_avg_16_upper = np.max([worst_group_errors_s1, worst_group_errors_s2, worst_group_errors_s3], axis=0)
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), test_errors_avg_16, marker='o', label='average test')
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), worst_group_errors_avg_16, marker='o', label='worst-group test')
plt.title("Resnet10 Width 16 0.0001 Weight Decay, Varying DP noise, reweighting average of 3 seeds")
plt.xlabel("DP-Noise_mult")
plt.ylabel("Error")

plt.fill_between(noises, test_errors_avg_16_lower, test_errors_avg_16_upper, alpha=0.2, color='tab:blue')
plt.fill_between(noises, worst_group_errors_avg_16_lower, worst_group_errors_avg_16_upper, alpha=0.2, color='tab:orange')

plt.legend()

# %% [markdown]
# ## Random seeds for width 32

# %%
dpw32_n03_reweight_s1 = pd.read_csv('logs/test_dp_w32_n03_reweight_seed1.csv')
dpw32_n04_reweight_s1 = pd.read_csv('logs/test_dp_w32_n04_reweight_seed1.csv')
dpw32_n05_reweight_s1 = pd.read_csv('logs/test_dp_w32_n05_reweight_seed1.csv')
dpw32_n08_reweight_s1 = pd.read_csv('logs/test_dp_w32_n08_reweight_seed1.csv')
dpw32_n11_reweight_s1 = pd.read_csv('logs/test_dp_w32_n11_reweight_seed1.csv')
dpw32_n14_reweight_s1 = pd.read_csv('logs/test_dp_w32_n14_reweight_seed1.csv')
dpw32_n17_reweight_s1 = pd.read_csv('logs/test_dp_w32_n17_reweight_seed1.csv')
dpw32_n20_reweight_s1 = pd.read_csv('logs/test_dp_w32_n20_reweight_seed1.csv')
dpw32_n23_reweight_s1 = pd.read_csv('logs/test_dp_w32_n23_reweight_seed1.csv')
dpw32_n26_reweight_s1 = pd.read_csv('logs/test_dp_w32_n26_reweight_seed1.csv')
dpw32_n29_reweight_s1 = pd.read_csv('logs/test_dp_w32_n29_reweight_seed1.csv')
dpw32_n32_reweight_s1 = pd.read_csv('logs/test_dp_w32_n32_reweight_seed1.csv')

# %%
dpw32_n03_worst_group_reweight_s1 = np.mean(np.array(dpw32_n03_reweight_s1['avg_loss_group:3'])[40:])
dpw32_n04_worst_group_reweight_s1 = np.mean(np.array(dpw32_n04_reweight_s1['avg_loss_group:3'])[40:])
dpw32_n05_worst_group_reweight_s1 = np.mean(np.array(dpw32_n05_reweight_s1['avg_loss_group:3'])[40:])
dpw32_n08_worst_group_reweight_s1 = np.mean(np.array(dpw32_n08_reweight_s1['avg_loss_group:3'])[40:])
dpw32_n11_worst_group_reweight_s1 = np.mean(np.array(dpw32_n11_reweight_s1['avg_loss_group:3'])[40:])
dpw32_n14_worst_group_reweight_s1 = np.mean(np.array(dpw32_n14_reweight_s1['avg_loss_group:3'])[40:])
dpw32_n17_worst_group_reweight_s1 = np.mean(np.array(dpw32_n17_reweight_s1['avg_loss_group:3'])[40:])
dpw32_n20_worst_group_reweight_s1 = np.mean(np.array(dpw32_n20_reweight_s1['avg_loss_group:3'])[40:])
dpw32_n23_worst_group_reweight_s1 = np.mean(np.array(dpw32_n23_reweight_s1['avg_loss_group:3'])[40:])
dpw32_n26_worst_group_reweight_s1 = np.mean(np.array(dpw32_n26_reweight_s1['avg_loss_group:3'])[40:])
dpw32_n29_worst_group_reweight_s1 = np.mean(np.array(dpw32_n29_reweight_s1['avg_loss_group:3'])[40:])
dpw32_n32_worst_group_reweight_s1 = np.mean(np.array(dpw32_n32_reweight_s1['avg_loss_group:3'])[40:])

dpw32_n03_reweight_last10_s1 = np.mean(np.array(dpw32_n03_reweight_s1['avg_actual_loss'])[45:])
dpw32_n04_reweight_last10_s1 = np.mean(np.array(dpw32_n04_reweight_s1['avg_actual_loss'])[45:])
dpw32_n05_reweight_last10_s1 = np.mean(np.array(dpw32_n05_reweight_s1['avg_actual_loss'])[45:])
dpw32_n08_reweight_last10_s1 = np.mean(np.array(dpw32_n08_reweight_s1['avg_actual_loss'])[45:])
dpw32_n11_reweight_last10_s1 = np.mean(np.array(dpw32_n11_reweight_s1['avg_actual_loss'])[45:])
dpw32_n14_reweight_last10_s1 = np.mean(np.array(dpw32_n14_reweight_s1['avg_actual_loss'])[45:])
dpw32_n17_reweight_last10_s1 = np.mean(np.array(dpw32_n17_reweight_s1['avg_actual_loss'])[45:])
dpw32_n20_reweight_last10_s1 = np.mean(np.array(dpw32_n20_reweight_s1['avg_actual_loss'])[45:])
dpw32_n23_reweight_last10_s1 = np.mean(np.array(dpw32_n23_reweight_s1['avg_actual_loss'])[45:])
dpw32_n26_reweight_last10_s1 = np.mean(np.array(dpw32_n26_reweight_s1['avg_actual_loss'])[45:])
dpw32_n29_reweight_last10_s1 = np.mean(np.array(dpw32_n29_reweight_s1['avg_actual_loss'])[45:])
dpw32_n32_reweight_last10_s1 = np.mean(np.array(dpw32_n32_reweight_s1['avg_actual_loss'])[45:])

# %%
test_errors_s1_smoothed_32 = np.array([dpw32_n03_reweight_last10_s1, dpw32_n04_reweight_last10_s1, dpw32_n05_reweight_last10_s1, dpw32_n08_reweight_last10_s1, dpw32_n11_reweight_last10_s1, dpw32_n14_reweight_last10_s1, dpw32_n17_reweight_last10_s1, dpw32_n20_reweight_last10_s1, dpw32_n23_reweight_last10_s1, dpw32_n26_reweight_last10_s1, dpw32_n29_reweight_last10_s1, dpw32_n32_reweight_last10_s1])
worst_group_errors_s1_smoothed_32 = np.array([dpw32_n03_worst_group_reweight_s1, dpw32_n04_worst_group_reweight_s1, dpw32_n05_worst_group_reweight_s1, dpw32_n08_worst_group_reweight_s1, dpw32_n11_worst_group_reweight_s1, dpw32_n14_worst_group_reweight_s1, dpw32_n17_worst_group_reweight_s1, dpw32_n20_worst_group_reweight_s1, dpw32_n23_worst_group_reweight_s1, dpw32_n26_worst_group_reweight_s1, dpw32_n29_worst_group_reweight_s1, dpw32_n32_worst_group_reweight_s1])
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), test_errors_s1_smoothed_32, marker='o', label='average test')
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), worst_group_errors_s1_smoothed_32, marker='o', label='worst-group test')
plt.title("Resnet10 Width 32 0.0001 Weight Decay, Varying DP noise, reweighting seed 1 smoothed")
plt.xlabel("DP-Noise_mult")
plt.ylabel("Error")
plt.legend()

# %%
test_errors_s1_32 = np.array([dpw32_n03_reweight_s1['avg_actual_loss'][49], dpw32_n04_reweight_s1['avg_actual_loss'][49], dpw32_n05_reweight_s1['avg_actual_loss'][49], dpw32_n08_reweight_s1['avg_actual_loss'][49], dpw32_n11_reweight_s1['avg_actual_loss'][49], dpw32_n14_reweight_s1['avg_actual_loss'][49], dpw32_n17_reweight_s1['avg_actual_loss'][49], dpw32_n20_reweight_s1['avg_actual_loss'][49], dpw32_n23_reweight_s1['avg_actual_loss'][49], dpw32_n26_reweight_s1['avg_actual_loss'][49], dpw32_n29_reweight_s1['avg_actual_loss'][49], dpw32_n32_reweight_s1['avg_actual_loss'][49]])
worst_group_errors_s1_32 = np.array([dpw32_n03_worst_group_reweight_s1, dpw32_n04_worst_group_reweight_s1, dpw32_n05_worst_group_reweight_s1, dpw32_n08_worst_group_reweight_s1, dpw32_n11_worst_group_reweight_s1, dpw32_n14_worst_group_reweight_s1, dpw32_n17_worst_group_reweight_s1, dpw32_n20_worst_group_reweight_s1, dpw32_n23_worst_group_reweight_s1, dpw32_n26_worst_group_reweight_s1, dpw32_n29_worst_group_reweight_s1, dpw32_n32_worst_group_reweight_s1]) #dpw32_n23_worst_group_reweight_s1, dpw32_n26_worst_group_reweight_s1, dpw32_n29_worst_group_reweight_s1, dpw32_n32_worst_group_reweight_s1
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), test_errors_s1_32, marker='o', label='average test')
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), worst_group_errors_s1_32, marker='o', label='worst-group test')
plt.title("Resnet10 Width 32 0.0001 Weight Decay, Varying DP noise, reweighting seed 1")
plt.xlabel("DP-Noise_mult")
plt.ylabel("Error")
plt.legend()

# %%
dpw32_n03_reweight_s2 = pd.read_csv('logs/test_dp_w32_n03_reweight_seed2.csv')
dpw32_n04_reweight_s2 = pd.read_csv('logs/test_dp_w32_n04_reweight_seed2.csv')
dpw32_n05_reweight_s2 = pd.read_csv('logs/test_dp_w32_n05_reweight_seed2.csv')
dpw32_n08_reweight_s2 = pd.read_csv('logs/test_dp_w32_n08_reweight_seed2.csv')
dpw32_n11_reweight_s2 = pd.read_csv('logs/test_dp_w32_n11_reweight_seed2.csv')
dpw32_n14_reweight_s2 = pd.read_csv('logs/test_dp_w32_n14_reweight_seed2.csv')
dpw32_n17_reweight_s2 = pd.read_csv('logs/test_dp_w32_n17_reweight_seed2.csv')
dpw32_n20_reweight_s2 = pd.read_csv('logs/test_dp_w32_n20_reweight_seed2.csv')
dpw32_n23_reweight_s2 = pd.read_csv('logs/test_dp_w32_n23_reweight_seed2.csv')
dpw32_n26_reweight_s2 = pd.read_csv('logs/test_dp_w32_n26_reweight_seed2.csv')
dpw32_n29_reweight_s2 = pd.read_csv('logs/test_dp_w32_n29_reweight_seed2.csv')
dpw32_n32_reweight_s2 = pd.read_csv('logs/test_dp_w32_n32_reweight_seed2.csv')

# %%
dpw32_n03_worst_group_reweight_s2 = np.mean(np.array(dpw32_n03_reweight_s2['avg_loss_group:3'])[40:])
dpw32_n04_worst_group_reweight_s2 = np.mean(np.array(dpw32_n04_reweight_s2['avg_loss_group:3'])[40:])
dpw32_n05_worst_group_reweight_s2 = np.mean(np.array(dpw32_n05_reweight_s2['avg_loss_group:3'])[40:])
dpw32_n08_worst_group_reweight_s2 = np.mean(np.array(dpw32_n08_reweight_s2['avg_loss_group:3'])[40:])
dpw32_n11_worst_group_reweight_s2 = np.mean(np.array(dpw32_n11_reweight_s2['avg_loss_group:3'])[40:])
dpw32_n14_worst_group_reweight_s2 = np.mean(np.array(dpw32_n14_reweight_s2['avg_loss_group:3'])[40:])
dpw32_n17_worst_group_reweight_s2 = np.mean(np.array(dpw32_n17_reweight_s2['avg_loss_group:3'])[40:])
dpw32_n20_worst_group_reweight_s2 = np.mean(np.array(dpw32_n20_reweight_s2['avg_loss_group:3'])[40:])
dpw32_n23_worst_group_reweight_s2 = np.mean(np.array(dpw32_n23_reweight_s2['avg_loss_group:3'])[40:])
dpw32_n26_worst_group_reweight_s2 = np.mean(np.array(dpw32_n26_reweight_s2['avg_loss_group:3'])[40:])
dpw32_n29_worst_group_reweight_s2 = np.mean(np.array(dpw32_n29_reweight_s2['avg_loss_group:3'])[40:])
dpw32_n32_worst_group_reweight_s2 = np.mean(np.array(dpw32_n32_reweight_s2['avg_loss_group:3'])[40:])

dpw32_n03_reweight_last10_s2 = np.mean(np.array(dpw32_n03_reweight_s2['avg_actual_loss'])[45:])
dpw32_n04_reweight_last10_s2 = np.mean(np.array(dpw32_n04_reweight_s2['avg_actual_loss'])[45:])
dpw32_n05_reweight_last10_s2 = np.mean(np.array(dpw32_n05_reweight_s2['avg_actual_loss'])[45:])
dpw32_n08_reweight_last10_s2 = np.mean(np.array(dpw32_n08_reweight_s2['avg_actual_loss'])[45:])
dpw32_n11_reweight_last10_s2 = np.mean(np.array(dpw32_n11_reweight_s2['avg_actual_loss'])[45:])
dpw32_n14_reweight_last10_s2 = np.mean(np.array(dpw32_n14_reweight_s2['avg_actual_loss'])[45:])
dpw32_n17_reweight_last10_s2 = np.mean(np.array(dpw32_n17_reweight_s2['avg_actual_loss'])[45:])
dpw32_n20_reweight_last10_s2 = np.mean(np.array(dpw32_n20_reweight_s2['avg_actual_loss'])[45:])
dpw32_n23_reweight_last10_s2 = np.mean(np.array(dpw32_n23_reweight_s2['avg_actual_loss'])[45:])
dpw32_n26_reweight_last10_s2 = np.mean(np.array(dpw32_n26_reweight_s2['avg_actual_loss'])[45:])
dpw32_n29_reweight_last10_s2 = np.mean(np.array(dpw32_n29_reweight_s2['avg_actual_loss'])[45:])
dpw32_n32_reweight_last10_s2 = np.mean(np.array(dpw32_n32_reweight_s2['avg_actual_loss'])[45:])

# %%
test_errors_s2_smoothed_32 = np.array([dpw32_n03_reweight_last10_s2, dpw32_n04_reweight_last10_s2, dpw32_n05_reweight_last10_s2, dpw32_n08_reweight_last10_s2, dpw32_n11_reweight_last10_s2, dpw32_n14_reweight_last10_s2, dpw32_n17_reweight_last10_s2, dpw32_n20_reweight_last10_s2, dpw32_n23_reweight_last10_s2, dpw32_n26_reweight_last10_s2, dpw32_n29_reweight_last10_s2, dpw32_n32_reweight_last10_s2])
worst_group_errors_s2_smoothed_32 = np.array([dpw32_n03_worst_group_reweight_s2, dpw32_n04_worst_group_reweight_s2, dpw32_n05_worst_group_reweight_s2, dpw32_n08_worst_group_reweight_s2, dpw32_n11_worst_group_reweight_s2, dpw32_n14_worst_group_reweight_s2, dpw32_n17_worst_group_reweight_s2, dpw32_n20_worst_group_reweight_s2, dpw32_n23_worst_group_reweight_s2, dpw32_n26_worst_group_reweight_s2, dpw32_n29_worst_group_reweight_s2, dpw32_n32_worst_group_reweight_s2])
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), test_errors_s2_smoothed_32, marker='o', label='average test')
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2., 2.3, 2.6, 2.9, 3.2]), worst_group_errors_s2_smoothed_32, marker='o', label='worst-group test')
plt.title("Resnet10 Width 32 0.0001 Weight Decay, Varying DP noise, reweighting seed 2 smoothed")
plt.xlabel("DP-Noise_mult")
plt.ylabel("Error")
plt.legend()

# %%
test_errors_s2_32 = np.array([dpw32_n03_reweight_s2['avg_actual_loss'][49], dpw32_n04_reweight_s2['avg_actual_loss'][49], dpw32_n05_reweight_s2['avg_actual_loss'][49], dpw32_n08_reweight_s2['avg_actual_loss'][49], dpw32_n11_reweight_s2['avg_actual_loss'][49], dpw32_n14_reweight_s2['avg_actual_loss'][49], dpw32_n17_reweight_s2['avg_actual_loss'][49], dpw32_n20_reweight_s2['avg_actual_loss'][49], dpw32_n23_reweight_s2['avg_actual_loss'][49], dpw32_n26_reweight_s2['avg_actual_loss'][49], dpw32_n29_reweight_s2['avg_actual_loss'][49], dpw32_n32_reweight_s2['avg_actual_loss'][49]])
worst_group_errors_s2_32 = np.array([dpw32_n03_worst_group_reweight_s2, dpw32_n04_worst_group_reweight_s2, dpw32_n05_worst_group_reweight_s2, dpw32_n08_worst_group_reweight_s2, dpw32_n11_worst_group_reweight_s2, dpw32_n14_worst_group_reweight_s2, dpw32_n17_worst_group_reweight_s2, dpw32_n20_worst_group_reweight_s2, dpw32_n23_worst_group_reweight_s2, dpw32_n26_worst_group_reweight_s2, dpw32_n29_worst_group_reweight_s2, dpw32_n32_worst_group_reweight_s2]) #dpw32_n23_worst_group_reweight_s2, dpw32_n26_worst_group_reweight_s2, dpw32_n29_worst_group_reweight_s2, dpw32_n32_worst_group_reweight_s2
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), test_errors_s2_32, marker='o', label='average test')
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), worst_group_errors_s2_32, marker='o', label='worst-group test')
plt.title("Resnet10 Width 32 0.0001 Weight Decay, Varying DP noise, reweighting seed 2")
plt.xlabel("DP-Noise_mult")
plt.ylabel("Error")
plt.legend()

# %%
dpw32_n03_reweight_s3 = pd.read_csv('logs/test_dp_w32_n03_reweight_seed3.csv')
dpw32_n04_reweight_s3 = pd.read_csv('logs/test_dp_w32_n04_reweight_seed3.csv')
dpw32_n05_reweight_s3 = pd.read_csv('logs/test_dp_w32_n05_reweight_seed3.csv')
dpw32_n08_reweight_s3 = pd.read_csv('logs/test_dp_w32_n08_reweight_seed3.csv')
dpw32_n11_reweight_s3 = pd.read_csv('logs/test_dp_w32_n11_reweight_seed3.csv')
dpw32_n14_reweight_s3 = pd.read_csv('logs/test_dp_w32_n14_reweight_seed3.csv')
dpw32_n17_reweight_s3 = pd.read_csv('logs/test_dp_w32_n17_reweight_seed3.csv')
dpw32_n20_reweight_s3 = pd.read_csv('logs/test_dp_w32_n20_reweight_seed3.csv')
dpw32_n23_reweight_s3 = pd.read_csv('logs/test_dp_w32_n23_reweight_seed3.csv')
dpw32_n26_reweight_s3 = pd.read_csv('logs/test_dp_w32_n26_reweight_seed3.csv')
dpw32_n29_reweight_s3 = pd.read_csv('logs/test_dp_w32_n29_reweight_seed3.csv')
dpw32_n32_reweight_s3 = pd.read_csv('logs/test_dp_w32_n32_reweight_seed3.csv')

# %%
dpw32_n03_worst_group_reweight_s3 = np.mean(np.array(dpw32_n03_reweight_s3['avg_loss_group:3'])[40:])
dpw32_n04_worst_group_reweight_s3 = np.mean(np.array(dpw32_n04_reweight_s3['avg_loss_group:3'])[40:])
dpw32_n05_worst_group_reweight_s3 = np.mean(np.array(dpw32_n05_reweight_s3['avg_loss_group:3'])[40:])
dpw32_n08_worst_group_reweight_s3 = np.mean(np.array(dpw32_n08_reweight_s3['avg_loss_group:3'])[40:])
dpw32_n11_worst_group_reweight_s3 = np.mean(np.array(dpw32_n11_reweight_s3['avg_loss_group:3'])[40:])
dpw32_n14_worst_group_reweight_s3 = np.mean(np.array(dpw32_n14_reweight_s3['avg_loss_group:3'])[40:])
dpw32_n17_worst_group_reweight_s3 = np.mean(np.array(dpw32_n17_reweight_s3['avg_loss_group:3'])[40:])
dpw32_n20_worst_group_reweight_s3 = np.mean(np.array(dpw32_n20_reweight_s3['avg_loss_group:3'])[40:])
dpw32_n23_worst_group_reweight_s3 = np.mean(np.array(dpw32_n23_reweight_s3['avg_loss_group:3'])[40:])
dpw32_n26_worst_group_reweight_s3 = np.mean(np.array(dpw32_n26_reweight_s3['avg_loss_group:3'])[40:])
dpw32_n29_worst_group_reweight_s3 = np.mean(np.array(dpw32_n29_reweight_s3['avg_loss_group:3'])[40:])
dpw32_n32_worst_group_reweight_s3 = np.mean(np.array(dpw32_n32_reweight_s3['avg_loss_group:3'])[40:])

dpw32_n03_reweight_last10_s3 = np.mean(np.array(dpw32_n03_reweight_s3['avg_actual_loss'])[45:])
dpw32_n04_reweight_last10_s3 = np.mean(np.array(dpw32_n04_reweight_s3['avg_actual_loss'])[45:])
dpw32_n05_reweight_last10_s3 = np.mean(np.array(dpw32_n05_reweight_s3['avg_actual_loss'])[45:])
dpw32_n08_reweight_last10_s3 = np.mean(np.array(dpw32_n08_reweight_s3['avg_actual_loss'])[45:])
dpw32_n11_reweight_last10_s3 = np.mean(np.array(dpw32_n11_reweight_s3['avg_actual_loss'])[45:])
dpw32_n14_reweight_last10_s3 = np.mean(np.array(dpw32_n14_reweight_s3['avg_actual_loss'])[45:])
dpw32_n17_reweight_last10_s3 = np.mean(np.array(dpw32_n17_reweight_s3['avg_actual_loss'])[45:])
dpw32_n20_reweight_last10_s3 = np.mean(np.array(dpw32_n20_reweight_s3['avg_actual_loss'])[45:])
dpw32_n23_reweight_last10_s3 = np.mean(np.array(dpw32_n23_reweight_s3['avg_actual_loss'])[45:])
dpw32_n26_reweight_last10_s3 = np.mean(np.array(dpw32_n26_reweight_s3['avg_actual_loss'])[45:])
dpw32_n29_reweight_last10_s3 = np.mean(np.array(dpw32_n29_reweight_s3['avg_actual_loss'])[45:])
dpw32_n32_reweight_last10_s3 = np.mean(np.array(dpw32_n32_reweight_s3['avg_actual_loss'])[45:])

# %%
test_errors_s3_smoothed_32 = np.array([dpw32_n03_reweight_last10_s3, dpw32_n04_reweight_last10_s3, dpw32_n05_reweight_last10_s3, dpw32_n08_reweight_last10_s3, dpw32_n11_reweight_last10_s3, dpw32_n14_reweight_last10_s3, dpw32_n17_reweight_last10_s3, dpw32_n20_reweight_last10_s3, dpw32_n23_reweight_last10_s3, dpw32_n26_reweight_last10_s3, dpw32_n29_reweight_last10_s3, dpw32_n32_reweight_last10_s3])
worst_group_errors_s3_smoothed_32 = np.array([dpw32_n03_worst_group_reweight_s3, dpw32_n04_worst_group_reweight_s3, dpw32_n05_worst_group_reweight_s3, dpw32_n08_worst_group_reweight_s3, dpw32_n11_worst_group_reweight_s3, dpw32_n14_worst_group_reweight_s3, dpw32_n17_worst_group_reweight_s3, dpw32_n20_worst_group_reweight_s3, dpw32_n23_worst_group_reweight_s3, dpw32_n26_worst_group_reweight_s3, dpw32_n29_worst_group_reweight_s3, dpw32_n32_worst_group_reweight_s3])
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), test_errors_s3_smoothed_32, marker='o', label='average test')
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), worst_group_errors_s3_smoothed_32, marker='o', label='worst-group test')
plt.title("Resnet10 Width 32 0.0001 Weight Decay, Varying DP noise, reweighting seed 3 smoothed")
plt.xlabel("DP-Noise_mult")
plt.ylabel("Error")
plt.legend()

# %%
test_errors_s3_32 = np.array([dpw32_n03_reweight_s3['avg_actual_loss'][49], dpw32_n04_reweight_s3['avg_actual_loss'][49], dpw32_n05_reweight_s3['avg_actual_loss'][49], dpw32_n08_reweight_s3['avg_actual_loss'][49], dpw32_n11_reweight_s3['avg_actual_loss'][49], dpw32_n14_reweight_s3['avg_actual_loss'][49], dpw32_n17_reweight_s3['avg_actual_loss'][49], dpw32_n20_reweight_s3['avg_actual_loss'][49], dpw32_n23_reweight_s3['avg_actual_loss'][49], dpw32_n26_reweight_s3['avg_actual_loss'][49], dpw32_n29_reweight_s3['avg_actual_loss'][49], dpw32_n32_reweight_s3['avg_actual_loss'][49]])
worst_group_errors_s3_32 = np.array([dpw32_n03_worst_group_reweight_s3, dpw32_n04_worst_group_reweight_s3, dpw32_n05_worst_group_reweight_s3, dpw32_n08_worst_group_reweight_s3, dpw32_n11_worst_group_reweight_s3, dpw32_n14_worst_group_reweight_s3, dpw32_n17_worst_group_reweight_s3, dpw32_n20_worst_group_reweight_s3, dpw32_n23_worst_group_reweight_s3, dpw32_n26_worst_group_reweight_s3, dpw32_n29_worst_group_reweight_s3, dpw32_n32_worst_group_reweight_s3]) #dpw32_n23_worst_group_reweight_s3, dpw32_n26_worst_group_reweight_s3, dpw32_n29_worst_group_reweight_s3, dpw32_n32_worst_group_reweight_s3
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), test_errors_s3_32, marker='o', label='average test')
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), worst_group_errors_s3_32, marker='o', label='worst-group test')
plt.title("Resnet10 Width 32 0.0001 Weight Decay, Varying DP noise, reweighting seed 3")
plt.xlabel("DP-Noise_mult")
plt.ylabel("Error")
plt.legend()

# %%
test_errors_smoothed_avg_32 = np.average([test_errors_s1_smoothed_32, test_errors_s2_smoothed_32, test_errors_s3_smoothed_32], axis=0)
worst_group_errors_smoothed_avg_32 = np.average([worst_group_errors_s1_32, worst_group_errors_s2_32, worst_group_errors_s3_32], axis=0)
noises = np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2])

test_errors_smoothed_avg_32_lower = np.min([test_errors_s1_smoothed_32, test_errors_s2_smoothed_32, test_errors_s3_smoothed_32], axis=0)
test_errors_smoothed_avg_32_upper = np.max([test_errors_s1_smoothed_32, test_errors_s2_smoothed_32, test_errors_s3_smoothed_32], axis=0)
worst_group_errors_smoothed_avg_32_lower = np.min([worst_group_errors_s1_32, worst_group_errors_s2_32, worst_group_errors_s3_32], axis=0)
worst_group_errors_smoothed_avg_32_upper = np.max([worst_group_errors_s1_32, worst_group_errors_s2_32, worst_group_errors_s3_32], axis=0)
plt.plot(noises, test_errors_smoothed_avg_32, marker='o', label='average test')
plt.plot(noises, worst_group_errors_smoothed_avg_32, marker='o', label='worst-group test')
plt.title("Width 32, 0.0001 Weight Decay, Varying DP noise, Reweighting, average of 3 seeds with smoothing")
plt.xlabel("DP-Noise_mult")
plt.ylabel("Error")
# ax = plt.subplots()
plt.fill_between(noises, test_errors_smoothed_avg_32_lower, test_errors_smoothed_avg_32_upper, alpha=0.2, color='tab:blue')
plt.fill_between(noises, worst_group_errors_smoothed_avg_32_lower, worst_group_errors_smoothed_avg_32_upper, alpha=0.2, color='tab:orange')

plt.legend()

# %%
test_errors_avg_32 = np.average([test_errors_s1_32, test_errors_s2_32, test_errors_s3_32], axis=0)
worst_group_errors_avg_32 = np.average([worst_group_errors_s1_32, worst_group_errors_s2_32, worst_group_errors_s3_32], axis=0)

test_errors_avg_32_lower = np.min([test_errors_s1_32, test_errors_s2_32, test_errors_s3_32], axis=0)
test_errors_avg_32_upper = np.max([test_errors_s1_32, test_errors_s2_32, test_errors_s3_32], axis=0)
worst_group_errors_avg_32_lower = np.min([worst_group_errors_s1_32, worst_group_errors_s2_32, worst_group_errors_s3_32], axis=0)
worst_group_errors_avg_32_upper = np.max([worst_group_errors_s1_32, worst_group_errors_s2_32, worst_group_errors_s3_32], axis=0)
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), test_errors_avg_32, marker='o', label='average test')
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), worst_group_errors_avg_32, marker='o', label='worst-group test')
plt.title("Resnet10 Width 32 0.0001 Weight Decay, Varying DP noise, reweighting average of 3 seeds")
plt.xlabel("DP-Noise_mult")
plt.ylabel("Error")

plt.fill_between(noises, test_errors_avg_32_lower, test_errors_avg_32_upper, alpha=0.2, color='tab:blue')
plt.fill_between(noises, worst_group_errors_avg_32_lower, worst_group_errors_avg_32_upper, alpha=0.2, color='tab:orange')

plt.legend()

# %% [markdown]
# ## Random seeds for width 64

# %%
dpw64_n03_reweight_s1 = pd.read_csv('logs/test_dp_w64_n03_reweight_seed1.csv')
dpw64_n04_reweight_s1 = pd.read_csv('logs/test_dp_w64_n04_reweight_seed1.csv')
dpw64_n05_reweight_s1 = pd.read_csv('logs/test_dp_w64_n05_reweight_seed1.csv')
dpw64_n08_reweight_s1 = pd.read_csv('logs/test_dp_w64_n08_reweight_seed1.csv')
dpw64_n11_reweight_s1 = pd.read_csv('logs/test_dp_w64_n11_reweight_seed1.csv')
dpw64_n14_reweight_s1 = pd.read_csv('logs/test_dp_w64_n14_reweight_seed1.csv')
dpw64_n17_reweight_s1 = pd.read_csv('logs/test_dp_w64_n17_reweight_seed1.csv')
dpw64_n20_reweight_s1 = pd.read_csv('logs/test_dp_w64_n20_reweight_seed1.csv')
dpw64_n23_reweight_s1 = pd.read_csv('logs/test_dp_w64_n23_reweight_seed1.csv')
dpw64_n26_reweight_s1 = pd.read_csv('logs/test_dp_w64_n26_reweight_seed1.csv')
dpw64_n29_reweight_s1 = pd.read_csv('logs/test_dp_w64_n29_reweight_seed1.csv')
dpw64_n32_reweight_s1 = pd.read_csv('logs/test_dp_w64_n32_reweight_seed1.csv')

# %%
dpw64_n03_worst_group_reweight_s1 = np.mean(np.array(dpw64_n03_reweight_s1['avg_loss_group:3'])[40:])
dpw64_n04_worst_group_reweight_s1 = np.mean(np.array(dpw64_n04_reweight_s1['avg_loss_group:3'])[40:])
dpw64_n05_worst_group_reweight_s1 = np.mean(np.array(dpw64_n05_reweight_s1['avg_loss_group:3'])[40:])
dpw64_n08_worst_group_reweight_s1 = np.mean(np.array(dpw64_n08_reweight_s1['avg_loss_group:3'])[40:])
dpw64_n11_worst_group_reweight_s1 = np.mean(np.array(dpw64_n11_reweight_s1['avg_loss_group:3'])[40:])
dpw64_n14_worst_group_reweight_s1 = np.mean(np.array(dpw64_n14_reweight_s1['avg_loss_group:3'])[40:])
dpw64_n17_worst_group_reweight_s1 = np.mean(np.array(dpw64_n17_reweight_s1['avg_loss_group:3'])[40:])
dpw64_n20_worst_group_reweight_s1 = np.mean(np.array(dpw64_n20_reweight_s1['avg_loss_group:3'])[40:])
dpw64_n23_worst_group_reweight_s1 = np.mean(np.array(dpw64_n23_reweight_s1['avg_loss_group:3'])[40:])
dpw64_n26_worst_group_reweight_s1 = np.mean(np.array(dpw64_n26_reweight_s1['avg_loss_group:3'])[40:])
dpw64_n29_worst_group_reweight_s1 = np.mean(np.array(dpw64_n29_reweight_s1['avg_loss_group:3'])[40:])
dpw64_n32_worst_group_reweight_s1 = np.mean(np.array(dpw64_n32_reweight_s1['avg_loss_group:3'])[40:])

dpw64_n03_reweight_last10_s1 = np.mean(np.array(dpw64_n03_reweight_s1['avg_actual_loss'])[45:])
dpw64_n04_reweight_last10_s1 = np.mean(np.array(dpw64_n04_reweight_s1['avg_actual_loss'])[45:])
dpw64_n05_reweight_last10_s1 = np.mean(np.array(dpw64_n05_reweight_s1['avg_actual_loss'])[45:])
dpw64_n08_reweight_last10_s1 = np.mean(np.array(dpw64_n08_reweight_s1['avg_actual_loss'])[45:])
dpw64_n11_reweight_last10_s1 = np.mean(np.array(dpw64_n11_reweight_s1['avg_actual_loss'])[45:])
dpw64_n14_reweight_last10_s1 = np.mean(np.array(dpw64_n14_reweight_s1['avg_actual_loss'])[45:])
dpw64_n17_reweight_last10_s1 = np.mean(np.array(dpw64_n17_reweight_s1['avg_actual_loss'])[45:])
dpw64_n20_reweight_last10_s1 = np.mean(np.array(dpw64_n20_reweight_s1['avg_actual_loss'])[45:])
dpw64_n23_reweight_last10_s1 = np.mean(np.array(dpw64_n23_reweight_s1['avg_actual_loss'])[45:])
dpw64_n26_reweight_last10_s1 = np.mean(np.array(dpw64_n26_reweight_s1['avg_actual_loss'])[45:])
dpw64_n29_reweight_last10_s1 = np.mean(np.array(dpw64_n29_reweight_s1['avg_actual_loss'])[45:])
dpw64_n32_reweight_last10_s1 = np.mean(np.array(dpw64_n32_reweight_s1['avg_actual_loss'])[45:])

# %%
test_errors_s1_smoothed_64 = np.array([dpw64_n03_reweight_last10_s1, dpw64_n04_reweight_last10_s1, dpw64_n05_reweight_last10_s1, dpw64_n08_reweight_last10_s1, dpw64_n11_reweight_last10_s1, dpw64_n14_reweight_last10_s1, dpw64_n17_reweight_last10_s1, dpw64_n20_reweight_last10_s1, dpw64_n23_reweight_last10_s1, dpw64_n26_reweight_last10_s1, dpw64_n29_reweight_last10_s1, dpw64_n32_reweight_last10_s1])
worst_group_errors_s1_smoothed_64 = np.array([dpw64_n03_worst_group_reweight_s1, dpw64_n04_worst_group_reweight_s1, dpw64_n05_worst_group_reweight_s1, dpw64_n08_worst_group_reweight_s1, dpw64_n11_worst_group_reweight_s1, dpw64_n14_worst_group_reweight_s1, dpw64_n17_worst_group_reweight_s1, dpw64_n20_worst_group_reweight_s1, dpw64_n23_worst_group_reweight_s1, dpw64_n26_worst_group_reweight_s1, dpw64_n29_worst_group_reweight_s1, dpw64_n32_worst_group_reweight_s1])
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), test_errors_s1_smoothed_64, marker='o', label='average test')
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), worst_group_errors_s1_smoothed_64, marker='o', label='worst-group test')
plt.title("Resnet10 Width 64 0.0001 Weight Decay, Varying DP noise, reweighting seed 1 smoothed")
plt.xlabel("DP-Noise_mult")
plt.ylabel("Error")
plt.legend()

# %%
test_errors_s1_64 = np.array([dpw64_n03_reweight_s1['avg_actual_loss'][49], dpw64_n04_reweight_s1['avg_actual_loss'][49], dpw64_n05_reweight_s1['avg_actual_loss'][49], dpw64_n08_reweight_s1['avg_actual_loss'][49], dpw64_n11_reweight_s1['avg_actual_loss'][49], dpw64_n14_reweight_s1['avg_actual_loss'][49], dpw64_n17_reweight_s1['avg_actual_loss'][49], dpw64_n20_reweight_s1['avg_actual_loss'][49], dpw64_n23_reweight_s1['avg_actual_loss'][49], dpw64_n26_reweight_s1['avg_actual_loss'][49], dpw64_n29_reweight_s1['avg_actual_loss'][49], dpw64_n32_reweight_s1['avg_actual_loss'][49]])
worst_group_errors_s1_64 = np.array([dpw64_n03_worst_group_reweight_s1, dpw64_n04_worst_group_reweight_s1, dpw64_n05_worst_group_reweight_s1, dpw64_n08_worst_group_reweight_s1, dpw64_n11_worst_group_reweight_s1, dpw64_n14_worst_group_reweight_s1, dpw64_n17_worst_group_reweight_s1, dpw64_n20_worst_group_reweight_s1, dpw64_n23_worst_group_reweight_s1, dpw64_n26_worst_group_reweight_s1, dpw64_n29_worst_group_reweight_s1, dpw64_n32_worst_group_reweight_s1])
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), test_errors_s1_64, marker='o', label='average test')
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), worst_group_errors_s1_64, marker='o', label='worst-group test')
plt.title("Resnet10 Width 64 0.0001 Weight Decay, Varying DP noise, reweighting seed 1")
plt.xlabel("DP-Noise_mult")
plt.ylabel("Error")
plt.legend()

# %%
dpw64_n03_reweight_s2 = pd.read_csv('logs/test_dp_w64_n03_reweight_seed2.csv')
dpw64_n04_reweight_s2 = pd.read_csv('logs/test_dp_w64_n04_reweight_seed2.csv')
dpw64_n05_reweight_s2 = pd.read_csv('logs/test_dp_w64_n05_reweight_seed2.csv')
dpw64_n08_reweight_s2 = pd.read_csv('logs/test_dp_w64_n08_reweight_seed2.csv')
dpw64_n11_reweight_s2 = pd.read_csv('logs/test_dp_w64_n11_reweight_seed2.csv')
dpw64_n14_reweight_s2 = pd.read_csv('logs/test_dp_w64_n14_reweight_seed2.csv')
dpw64_n17_reweight_s2 = pd.read_csv('logs/test_dp_w64_n17_reweight_seed2.csv')
dpw64_n20_reweight_s2 = pd.read_csv('logs/test_dp_w64_n20_reweight_seed2.csv')
dpw64_n23_reweight_s2 = pd.read_csv('logs/test_dp_w64_n23_reweight_seed2.csv')
dpw64_n26_reweight_s2 = pd.read_csv('logs/test_dp_w64_n26_reweight_seed2.csv')
dpw64_n29_reweight_s2 = pd.read_csv('logs/test_dp_w64_n29_reweight_seed2.csv')
dpw64_n32_reweight_s2 = pd.read_csv('logs/test_dp_w64_n32_reweight_seed2.csv')

# %%
dpw64_n03_worst_group_reweight_s2 = np.mean(np.array(dpw64_n03_reweight_s2['avg_loss_group:3'])[40:])
dpw64_n04_worst_group_reweight_s2 = np.mean(np.array(dpw64_n04_reweight_s2['avg_loss_group:3'])[40:])
dpw64_n05_worst_group_reweight_s2 = np.mean(np.array(dpw64_n05_reweight_s2['avg_loss_group:3'])[40:])
dpw64_n08_worst_group_reweight_s2 = np.mean(np.array(dpw64_n08_reweight_s2['avg_loss_group:3'])[40:])
dpw64_n11_worst_group_reweight_s2 = np.mean(np.array(dpw64_n11_reweight_s2['avg_loss_group:3'])[40:])
dpw64_n14_worst_group_reweight_s2 = np.mean(np.array(dpw64_n14_reweight_s2['avg_loss_group:3'])[40:])
dpw64_n17_worst_group_reweight_s2 = np.mean(np.array(dpw64_n17_reweight_s2['avg_loss_group:3'])[40:])
dpw64_n20_worst_group_reweight_s2 = np.mean(np.array(dpw64_n20_reweight_s2['avg_loss_group:3'])[40:])
dpw64_n23_worst_group_reweight_s2 = np.mean(np.array(dpw64_n23_reweight_s2['avg_loss_group:3'])[40:])
dpw64_n26_worst_group_reweight_s2 = np.mean(np.array(dpw64_n26_reweight_s2['avg_loss_group:3'])[40:])
dpw64_n29_worst_group_reweight_s2 = np.mean(np.array(dpw64_n29_reweight_s2['avg_loss_group:3'])[40:])
dpw64_n32_worst_group_reweight_s2 = np.mean(np.array(dpw64_n32_reweight_s2['avg_loss_group:3'])[40:])

dpw64_n03_reweight_last10_s2 = np.mean(np.array(dpw64_n03_reweight_s2['avg_actual_loss'])[45:])
dpw64_n04_reweight_last10_s2 = np.mean(np.array(dpw64_n04_reweight_s2['avg_actual_loss'])[45:])
dpw64_n05_reweight_last10_s2 = np.mean(np.array(dpw64_n05_reweight_s2['avg_actual_loss'])[45:])
dpw64_n08_reweight_last10_s2 = np.mean(np.array(dpw64_n08_reweight_s2['avg_actual_loss'])[45:])
dpw64_n11_reweight_last10_s2 = np.mean(np.array(dpw64_n11_reweight_s2['avg_actual_loss'])[45:])
dpw64_n14_reweight_last10_s2 = np.mean(np.array(dpw64_n14_reweight_s2['avg_actual_loss'])[45:])
dpw64_n17_reweight_last10_s2 = np.mean(np.array(dpw64_n17_reweight_s2['avg_actual_loss'])[45:])
dpw64_n20_reweight_last10_s2 = np.mean(np.array(dpw64_n20_reweight_s2['avg_actual_loss'])[45:])
dpw64_n23_reweight_last10_s2 = np.mean(np.array(dpw64_n23_reweight_s2['avg_actual_loss'])[45:])
dpw64_n26_reweight_last10_s2 = np.mean(np.array(dpw64_n26_reweight_s2['avg_actual_loss'])[45:])
dpw64_n29_reweight_last10_s2 = np.mean(np.array(dpw64_n29_reweight_s2['avg_actual_loss'])[45:])
dpw64_n32_reweight_last10_s2 = np.mean(np.array(dpw64_n32_reweight_s2['avg_actual_loss'])[45:])

# %%
test_errors_s2_smoothed_64 = np.array([dpw64_n03_reweight_last10_s2, dpw64_n04_reweight_last10_s2, dpw64_n05_reweight_last10_s2, dpw64_n08_reweight_last10_s2, dpw64_n11_reweight_last10_s2, dpw64_n14_reweight_last10_s2, dpw64_n17_reweight_last10_s2, dpw64_n20_reweight_last10_s2, dpw64_n23_reweight_last10_s2, dpw64_n26_reweight_last10_s2, dpw64_n29_reweight_last10_s2, dpw64_n32_reweight_last10_s2])
worst_group_errors_s2_smoothed_64 = np.array([dpw64_n03_worst_group_reweight_s2, dpw64_n04_worst_group_reweight_s2, dpw64_n05_worst_group_reweight_s2, dpw64_n08_worst_group_reweight_s2, dpw64_n11_worst_group_reweight_s2, dpw64_n14_worst_group_reweight_s2, dpw64_n17_worst_group_reweight_s2, dpw64_n20_worst_group_reweight_s2, dpw64_n23_worst_group_reweight_s2, dpw64_n26_worst_group_reweight_s2, dpw64_n29_worst_group_reweight_s2, dpw64_n32_worst_group_reweight_s2])
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), test_errors_s2_smoothed_64, marker='o', label='average test')
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), worst_group_errors_s2_smoothed_64, marker='o', label='worst-group test')
plt.title("Resnet10 Width 64 0.0001 Weight Decay, Varying DP noise, reweighting seed 2 smoothed")
plt.xlabel("DP-Noise_mult")
plt.ylabel("Error")
plt.legend()

# %%
test_errors_s2_64 = np.array([dpw64_n03_reweight_s2['avg_actual_loss'][49], dpw64_n04_reweight_s2['avg_actual_loss'][49], dpw64_n05_reweight_s2['avg_actual_loss'][49], dpw64_n08_reweight_s2['avg_actual_loss'][49], dpw64_n11_reweight_s2['avg_actual_loss'][49], dpw64_n14_reweight_s2['avg_actual_loss'][49], dpw64_n17_reweight_s2['avg_actual_loss'][49], dpw64_n20_reweight_s2['avg_actual_loss'][49], dpw64_n23_reweight_s2['avg_actual_loss'][49], dpw64_n26_reweight_s2['avg_actual_loss'][49], dpw64_n29_reweight_s2['avg_actual_loss'][49], dpw64_n32_reweight_s2['avg_actual_loss'][49]])
worst_group_errors_s2_64 = np.array([dpw64_n03_worst_group_reweight_s2, dpw64_n04_worst_group_reweight_s2, dpw64_n05_worst_group_reweight_s2, dpw64_n08_worst_group_reweight_s2, dpw64_n11_worst_group_reweight_s2, dpw64_n14_worst_group_reweight_s2, dpw64_n17_worst_group_reweight_s2, dpw64_n20_worst_group_reweight_s2, dpw64_n23_worst_group_reweight_s2, dpw64_n26_worst_group_reweight_s2, dpw64_n29_worst_group_reweight_s2, dpw64_n32_worst_group_reweight_s2])
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), test_errors_s2_64, marker='o', label='average test')
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), worst_group_errors_s2_64, marker='o', label='worst-group test')
plt.title("Resnet10 Width 64 0.0001 Weight Decay, Varying DP noise, reweighting seed 2")
plt.xlabel("DP-Noise_mult")
plt.ylabel("Error")
plt.legend()

# %%
dpw64_n03_reweight_s3 = pd.read_csv('logs/test_dp_w64_n03_reweight_seed3.csv')
dpw64_n04_reweight_s3 = pd.read_csv('logs/test_dp_w64_n04_reweight_seed3.csv')
dpw64_n05_reweight_s3 = pd.read_csv('logs/test_dp_w64_n05_reweight_seed3.csv')
dpw64_n08_reweight_s3 = pd.read_csv('logs/test_dp_w64_n08_reweight_seed3.csv')
dpw64_n11_reweight_s3 = pd.read_csv('logs/test_dp_w64_n11_reweight_seed3.csv')
dpw64_n14_reweight_s3 = pd.read_csv('logs/test_dp_w64_n14_reweight_seed3.csv')
dpw64_n17_reweight_s3 = pd.read_csv('logs/test_dp_w64_n17_reweight_seed3.csv')
dpw64_n20_reweight_s3 = pd.read_csv('logs/test_dp_w64_n20_reweight_seed3.csv')
dpw64_n23_reweight_s3 = pd.read_csv('logs/test_dp_w64_n23_reweight_seed3.csv')
dpw64_n26_reweight_s3 = pd.read_csv('logs/test_dp_w64_n26_reweight_seed3.csv')
dpw64_n29_reweight_s3 = pd.read_csv('logs/test_dp_w64_n29_reweight_seed3.csv')
dpw64_n32_reweight_s3 = pd.read_csv('logs/test_dp_w64_n32_reweight_seed3.csv')

# %%
dpw64_n03_worst_group_reweight_s3 = np.mean(np.array(dpw64_n03_reweight_s3['avg_loss_group:3'])[40:])
dpw64_n04_worst_group_reweight_s3 = np.mean(np.array(dpw64_n04_reweight_s3['avg_loss_group:3'])[40:])
dpw64_n05_worst_group_reweight_s3 = np.mean(np.array(dpw64_n05_reweight_s3['avg_loss_group:3'])[40:])
dpw64_n08_worst_group_reweight_s3 = np.mean(np.array(dpw64_n08_reweight_s3['avg_loss_group:3'])[40:])
dpw64_n11_worst_group_reweight_s3 = np.mean(np.array(dpw64_n11_reweight_s3['avg_loss_group:3'])[40:])
dpw64_n14_worst_group_reweight_s3 = np.mean(np.array(dpw64_n14_reweight_s3['avg_loss_group:3'])[40:])
dpw64_n17_worst_group_reweight_s3 = np.mean(np.array(dpw64_n17_reweight_s3['avg_loss_group:3'])[40:])
dpw64_n20_worst_group_reweight_s3 = np.mean(np.array(dpw64_n20_reweight_s3['avg_loss_group:3'])[40:])
dpw64_n23_worst_group_reweight_s3 = np.mean(np.array(dpw64_n23_reweight_s3['avg_loss_group:3'])[40:])
dpw64_n26_worst_group_reweight_s3 = np.mean(np.array(dpw64_n26_reweight_s3['avg_loss_group:3'])[40:])
dpw64_n29_worst_group_reweight_s3 = np.mean(np.array(dpw64_n29_reweight_s3['avg_loss_group:3'])[40:])
dpw64_n32_worst_group_reweight_s3 = np.mean(np.array(dpw64_n32_reweight_s3['avg_loss_group:3'])[40:])

dpw64_n03_reweight_last10_s3 = np.mean(np.array(dpw64_n03_reweight_s3['avg_actual_loss'])[45:])
dpw64_n04_reweight_last10_s3 = np.mean(np.array(dpw64_n04_reweight_s3['avg_actual_loss'])[45:])
dpw64_n05_reweight_last10_s3 = np.mean(np.array(dpw64_n05_reweight_s3['avg_actual_loss'])[45:])
dpw64_n08_reweight_last10_s3 = np.mean(np.array(dpw64_n08_reweight_s3['avg_actual_loss'])[45:])
dpw64_n11_reweight_last10_s3 = np.mean(np.array(dpw64_n11_reweight_s3['avg_actual_loss'])[45:])
dpw64_n14_reweight_last10_s3 = np.mean(np.array(dpw64_n14_reweight_s3['avg_actual_loss'])[45:])
dpw64_n17_reweight_last10_s3 = np.mean(np.array(dpw64_n17_reweight_s3['avg_actual_loss'])[45:])
dpw64_n20_reweight_last10_s3 = np.mean(np.array(dpw64_n20_reweight_s3['avg_actual_loss'])[45:])
dpw64_n23_reweight_last10_s3 = np.mean(np.array(dpw64_n23_reweight_s3['avg_actual_loss'])[45:])
dpw64_n26_reweight_last10_s3 = np.mean(np.array(dpw64_n26_reweight_s3['avg_actual_loss'])[45:])
dpw64_n29_reweight_last10_s3 = np.mean(np.array(dpw64_n29_reweight_s3['avg_actual_loss'])[45:])
dpw64_n32_reweight_last10_s3 = np.mean(np.array(dpw64_n32_reweight_s3['avg_actual_loss'])[45:])

# %%
test_errors_s3_smoothed_64 = np.array([dpw64_n03_reweight_last10_s3, dpw64_n04_reweight_last10_s3, dpw64_n05_reweight_last10_s3, dpw64_n08_reweight_last10_s3, dpw64_n11_reweight_last10_s3, dpw64_n14_reweight_last10_s3, dpw64_n17_reweight_last10_s3, dpw64_n20_reweight_last10_s3, dpw64_n23_reweight_last10_s3, dpw64_n26_reweight_last10_s3, dpw64_n29_reweight_last10_s3, dpw64_n32_reweight_last10_s3])
worst_group_errors_s3_smoothed_64 = np.array([dpw64_n03_worst_group_reweight_s3, dpw64_n04_worst_group_reweight_s3, dpw64_n05_worst_group_reweight_s3, dpw64_n08_worst_group_reweight_s3, dpw64_n11_worst_group_reweight_s3, dpw64_n14_worst_group_reweight_s3, dpw64_n17_worst_group_reweight_s3, dpw64_n20_worst_group_reweight_s3, dpw64_n23_worst_group_reweight_s3, dpw64_n26_worst_group_reweight_s3, dpw64_n29_worst_group_reweight_s3, dpw64_n32_worst_group_reweight_s3])
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), test_errors_s3_smoothed_64, marker='o', label='average test')
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), worst_group_errors_s3_smoothed_64, marker='o', label='worst-group test')
plt.title("Resnet10 Width 64 0.0001 Weight Decay, Varying DP noise, reweighting seed 3 smoothed")
plt.xlabel("DP-Noise_mult")
plt.ylabel("Error")
plt.legend()

# %%
test_errors_s3_64 = np.array([dpw64_n03_reweight_s3['avg_actual_loss'][49], dpw64_n04_reweight_s3['avg_actual_loss'][49], dpw64_n05_reweight_s3['avg_actual_loss'][49], dpw64_n08_reweight_s3['avg_actual_loss'][49], dpw64_n11_reweight_s3['avg_actual_loss'][49], dpw64_n14_reweight_s3['avg_actual_loss'][49], dpw64_n17_reweight_s3['avg_actual_loss'][49], dpw64_n20_reweight_s3['avg_actual_loss'][49], dpw64_n23_reweight_s3['avg_actual_loss'][49], dpw64_n26_reweight_s3['avg_actual_loss'][49], dpw64_n29_reweight_s3['avg_actual_loss'][49], dpw64_n32_reweight_s3['avg_actual_loss'][49]])
worst_group_errors_s3_64 = np.array([dpw64_n03_worst_group_reweight_s3, dpw64_n04_worst_group_reweight_s3, dpw64_n05_worst_group_reweight_s3, dpw64_n08_worst_group_reweight_s3, dpw64_n11_worst_group_reweight_s3, dpw64_n14_worst_group_reweight_s3, dpw64_n17_worst_group_reweight_s3, dpw64_n20_worst_group_reweight_s3, dpw64_n23_worst_group_reweight_s3, dpw64_n26_worst_group_reweight_s3, dpw64_n29_worst_group_reweight_s3, dpw64_n32_worst_group_reweight_s3])
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), test_errors_s3_64, marker='o', label='average test')
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), worst_group_errors_s3_64, marker='o', label='worst-group test')
plt.title("Resnet10 Width 64 0.0001 Weight Decay, Varying DP noise, reweighting seed 3")
plt.xlabel("DP-Noise_mult")
plt.ylabel("Error")
plt.legend()

# %%
test_errors_smoothed_avg_64 = np.average([test_errors_s1_smoothed_64, test_errors_s2_smoothed_64, test_errors_s3_smoothed_64], axis=0)
worst_group_errors_smoothed_avg_64 = np.average([worst_group_errors_s1_64, worst_group_errors_s2_64, worst_group_errors_s3_64], axis=0)
noises = np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2])

test_errors_smoothed_avg_64_lower = np.min([test_errors_s1_smoothed_64, test_errors_s2_smoothed_64, test_errors_s3_smoothed_64], axis=0)
test_errors_smoothed_avg_64_upper = np.max([test_errors_s1_smoothed_64, test_errors_s2_smoothed_64, test_errors_s3_smoothed_64], axis=0)
worst_group_errors_smoothed_avg_64_lower = np.min([worst_group_errors_s1_64, worst_group_errors_s2_64, worst_group_errors_s3_64], axis=0)
worst_group_errors_smoothed_avg_64_upper = np.max([worst_group_errors_s1_64, worst_group_errors_s2_64, worst_group_errors_s3_64], axis=0)
plt.plot(noises, test_errors_smoothed_avg_64, marker='o', label='average test')
plt.plot(noises, worst_group_errors_smoothed_avg_64, marker='o', label='worst-group test')
plt.title("Width 64, 0.0001 Weight Decay, Varying DP noise, Reweighting, average of 3 seeds with smoothing")
plt.xlabel("DP-Noise_mult")
plt.ylabel("Error")
# ax = plt.subplots()
plt.fill_between(noises, test_errors_smoothed_avg_64_lower, test_errors_smoothed_avg_64_upper, alpha=0.2, color='tab:blue')
plt.fill_between(noises, worst_group_errors_smoothed_avg_64_lower, worst_group_errors_smoothed_avg_64_upper, alpha=0.2, color='tab:orange')

plt.legend()

# %%
test_errors_avg_64 = np.average([test_errors_s1_64, test_errors_s2_64, test_errors_s3_64], axis=0)
worst_group_errors_avg_64 = np.average([worst_group_errors_s1_64, worst_group_errors_s2_64, worst_group_errors_s3_64], axis=0)

test_errors_avg_64_lower = np.min([test_errors_s1_64, test_errors_s2_64, test_errors_s3_64], axis=0)
test_errors_avg_64_upper = np.max([test_errors_s1_64, test_errors_s2_64, test_errors_s3_64], axis=0)
worst_group_errors_avg_64_lower = np.min([worst_group_errors_s1_64, worst_group_errors_s2_64, worst_group_errors_s3_64], axis=0)
worst_group_errors_avg_64_upper = np.max([worst_group_errors_s1_64, worst_group_errors_s2_64, worst_group_errors_s3_64], axis=0)
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), test_errors_avg_64, marker='o', label='average test')
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), worst_group_errors_avg_64, marker='o', label='worst-group test')
plt.title("Resnet10 Width 64 0.0001 Weight Decay, Varying DP noise, reweighting average of 3 seeds")
plt.xlabel("DP-Noise_mult")
plt.ylabel("Error")

plt.fill_between(noises, test_errors_avg_64_lower, test_errors_avg_64_upper, alpha=0.2, color='tab:blue')
plt.fill_between(noises, worst_group_errors_avg_64_lower, worst_group_errors_avg_64_upper, alpha=0.2, color='tab:orange')

plt.legend()

# %% [markdown]
# ## Random seeds for Width 96

# %%
dpw96_n03_reweight_s1 = pd.read_csv('logs/test_dp_w96_n03_reweight_seed1.csv')
dpw96_n04_reweight_s1 = pd.read_csv('logs/test_dp_w96_n04_reweight_seed1.csv')
dpw96_n05_reweight_s1 = pd.read_csv('logs/test_dp_w96_n05_reweight_seed1.csv')
dpw96_n08_reweight_s1 = pd.read_csv('logs/test_dp_w96_n08_reweight_seed1.csv')
dpw96_n11_reweight_s1 = pd.read_csv('logs/test_dp_w96_n11_reweight_seed1.csv')
dpw96_n14_reweight_s1 = pd.read_csv('logs/test_dp_w96_n14_reweight_seed1.csv')
dpw96_n17_reweight_s1 = pd.read_csv('logs/test_dp_w96_n17_reweight_seed1.csv')
dpw96_n20_reweight_s1 = pd.read_csv('logs/test_dp_w96_n20_reweight_seed1.csv')
# dpw96_n23_reweight_s1 = pd.read_csv('logs/test_dp_w96_n23_reweight_seed1.csv')
dpw96_n26_reweight_s1 = pd.read_csv('logs/test_dp_w96_n26_reweight_seed1.csv')
dpw96_n29_reweight_s1 = pd.read_csv('logs/test_dp_w96_n29_reweight_seed1.csv')
# dpw96_n32_reweight_s1 = pd.read_csv('logs/test_dp_w96_n32_reweight_seed1.csv')


dpw96_n03_worst_group_reweight_s1 = np.mean(np.array(dpw96_n03_reweight_s1['avg_loss_group:3'])[40:])
dpw96_n04_worst_group_reweight_s1 = np.mean(np.array(dpw96_n04_reweight_s1['avg_loss_group:3'])[40:])
dpw96_n05_worst_group_reweight_s1 = np.mean(np.array(dpw96_n05_reweight_s1['avg_loss_group:3'])[40:])
dpw96_n08_worst_group_reweight_s1 = np.mean(np.array(dpw96_n08_reweight_s1['avg_loss_group:3'])[40:])
dpw96_n11_worst_group_reweight_s1 = np.mean(np.array(dpw96_n11_reweight_s1['avg_loss_group:3'])[40:])
dpw96_n14_worst_group_reweight_s1 = np.mean(np.array(dpw96_n14_reweight_s1['avg_loss_group:3'])[40:])
dpw96_n17_worst_group_reweight_s1 = np.mean(np.array(dpw96_n17_reweight_s1['avg_loss_group:3'])[40:])
dpw96_n20_worst_group_reweight_s1 = np.mean(np.array(dpw96_n20_reweight_s1['avg_loss_group:3'])[40:])
# dpw96_n23_worst_group_reweight_s1 = np.mean(np.array(dpw96_n23_reweight_s1['avg_loss_group:3'])[40:])
dpw96_n26_worst_group_reweight_s1 = np.mean(np.array(dpw96_n26_reweight_s1['avg_loss_group:3'])[40:])
dpw96_n29_worst_group_reweight_s1 = np.mean(np.array(dpw96_n29_reweight_s1['avg_loss_group:3'])[40:])
# dpw96_n32_worst_group_reweight_s1 = np.mean(np.array(dpw96_n32_reweight_s1['avg_loss_group:3'])[40:])

dpw96_n03_reweight_last10_s1 = np.mean(np.array(dpw96_n03_reweight_s1['avg_actual_loss'])[45:])
dpw96_n04_reweight_last10_s1 = np.mean(np.array(dpw96_n04_reweight_s1['avg_actual_loss'])[45:])
dpw96_n05_reweight_last10_s1 = np.mean(np.array(dpw96_n05_reweight_s1['avg_actual_loss'])[45:])
dpw96_n08_reweight_last10_s1 = np.mean(np.array(dpw96_n08_reweight_s1['avg_actual_loss'])[45:])
dpw96_n11_reweight_last10_s1 = np.mean(np.array(dpw96_n11_reweight_s1['avg_actual_loss'])[45:])
dpw96_n14_reweight_last10_s1 = np.mean(np.array(dpw96_n14_reweight_s1['avg_actual_loss'])[45:])
dpw96_n17_reweight_last10_s1 = np.mean(np.array(dpw96_n17_reweight_s1['avg_actual_loss'])[45:])
dpw96_n20_reweight_last10_s1 = np.mean(np.array(dpw96_n20_reweight_s1['avg_actual_loss'])[45:])
# dpw96_n23_reweight_last10_s1 = np.mean(np.array(dpw96_n23_reweight_s1['avg_actual_loss'])[45:])
dpw96_n26_reweight_last10_s1 = np.mean(np.array(dpw96_n26_reweight_s1['avg_actual_loss'])[45:])
dpw96_n29_reweight_last10_s1 = np.mean(np.array(dpw96_n29_reweight_s1['avg_actual_loss'])[45:])
# dpw96_n32_reweight_last10_s1 = np.mean(np.array(dpw96_n32_reweight_s1['avg_actual_loss'])[45:])


test_errors_s1_smoothed_96 = np.array([dpw96_n03_reweight_last10_s1, dpw96_n04_reweight_last10_s1, dpw96_n05_reweight_last10_s1, dpw96_n08_reweight_last10_s1, dpw96_n11_reweight_last10_s1, dpw96_n14_reweight_last10_s1, dpw96_n17_reweight_last10_s1, dpw96_n20_reweight_last10_s1, dpw96_n26_reweight_last10_s1, dpw96_n29_reweight_last10_s1])
worst_group_errors_s1_smoothed_96 = np.array([dpw96_n03_worst_group_reweight_s1, dpw96_n04_worst_group_reweight_s1, dpw96_n05_worst_group_reweight_s1, dpw96_n08_worst_group_reweight_s1, dpw96_n11_worst_group_reweight_s1, dpw96_n14_worst_group_reweight_s1, dpw96_n17_worst_group_reweight_s1, dpw96_n20_worst_group_reweight_s1, dpw96_n26_worst_group_reweight_s1, dpw96_n29_worst_group_reweight_s1])
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.6, 2.9]), test_errors_s1_smoothed_96, marker='o', label='average test')
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.6, 2.9]), worst_group_errors_s1_smoothed_96, marker='o', label='worst-group test')
plt.title("Resnet10 Width 96 0.0001 Weight Decay, Varying DP noise, reweighting seed 1 smoothed")
plt.xlabel("DP-Noise_mult")
plt.ylabel("Error")
plt.legend()

# %%
test_errors_s1_64 = np.array([dpw64_n03_reweight_s1['avg_actual_loss'][49], dpw64_n04_reweight_s1['avg_actual_loss'][49], dpw64_n05_reweight_s1['avg_actual_loss'][49], dpw64_n08_reweight_s1['avg_actual_loss'][49], dpw64_n11_reweight_s1['avg_actual_loss'][49], dpw64_n14_reweight_s1['avg_actual_loss'][49], dpw64_n17_reweight_s1['avg_actual_loss'][49], dpw64_n20_reweight_s1['avg_actual_loss'][49], dpw64_n23_reweight_s1['avg_actual_loss'][49], dpw64_n26_reweight_s1['avg_actual_loss'][49], dpw64_n29_reweight_s1['avg_actual_loss'][49], dpw64_n32_reweight_s1['avg_actual_loss'][49]])
worst_group_errors_s1_64 = np.array([dpw64_n03_worst_group_reweight_s1, dpw64_n04_worst_group_reweight_s1, dpw64_n05_worst_group_reweight_s1, dpw64_n08_worst_group_reweight_s1, dpw64_n11_worst_group_reweight_s1, dpw64_n14_worst_group_reweight_s1, dpw64_n17_worst_group_reweight_s1, dpw64_n20_worst_group_reweight_s1, dpw64_n23_worst_group_reweight_s1, dpw64_n26_worst_group_reweight_s1, dpw64_n29_worst_group_reweight_s1, dpw64_n32_worst_group_reweight_s1])
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), test_errors_s1_64, marker='o', label='average test')
plt.plot(np.array([0.3, 0.4, 0.5, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.9, 3.2]), worst_group_errors_s1_64, marker='o', label='worst-group test')
plt.title("Resnet10 Width 64 0.0001 Weight Decay, Varying DP noise, reweighting seed 1")
plt.xlabel("DP-Noise_mult")
plt.ylabel("Error")
plt.legend()

# %% [markdown]
# ## Training curves for varying noise plots

# %%
dp_w16_n05_train = pd.read_csv("logs/train_dp_w16_n05_reweight.csv")
dp_w16_n05_train = dp_w16_n05_train.groupby(['epoch']).mean()

dp_w16_n08_train = pd.read_csv("logs/train_dp_w16_n08_reweight.csv")
dp_w16_n08_train = dp_w16_n08_train.groupby(['epoch']).mean()

dp_w16_n11_train = pd.read_csv("logs/train_dp_w16_n11_reweight.csv")
dp_w16_n11_train = dp_w16_n11_train.groupby(['epoch']).mean()

dp_w16_n14_train = pd.read_csv("logs/train_dp_w16_n14_reweight.csv")
dp_w16_n14_train = dp_w16_n14_train.groupby(['epoch']).mean()

dp_w16_n17_train = pd.read_csv("logs/train_dp_w16_n17_reweight.csv")
dp_w16_n17_train = dp_w16_n17_train.groupby(['epoch']).mean()

dp_w16_n20_train = pd.read_csv("logs/train_dp_w16_n20_reweight.csv")
dp_w16_n20_train = dp_w16_n20_train.groupby(['epoch']).mean()

dp_w16_n23_train = pd.read_csv("logs/train_dp_w16_n23_reweight.csv")
dp_w16_n23_train = dp_w16_n23_train.groupby(['epoch']).mean()

dp_w16_n26_train = pd.read_csv("logs/train_dp_w16_n26_reweight.csv")
dp_w16_n26_train = dp_w16_n26_train.groupby(['epoch']).mean()

dp_w16_n29_train = pd.read_csv("logs/train_dp_w16_n29_reweight.csv")
dp_w16_n29_train = dp_w16_n29_train.groupby(['epoch']).mean()

dp_w16_n32_train = pd.read_csv("logs/train_dp_w16_n32_reweight.csv")
dp_w16_n32_train = dp_w16_n32_train.groupby(['epoch']).mean()

# %%
plt.plot(dp_w16_n05_train['avg_actual_loss'], label="noise_mult 0.5")
plt.plot(dp_w16_n08_train['avg_actual_loss'], label="noise_mult 0.8")
plt.plot(dp_w16_n11_train['avg_actual_loss'], label="noise_mult 1.1")
plt.plot(dp_w16_n14_train['avg_actual_loss'], label="noise_mult 1.4")
plt.plot(dp_w16_n17_train['avg_actual_loss'], label="noise_mult 1.7")
plt.plot(dp_w16_n20_train['avg_actual_loss'], label="noise_mult 2.0")
plt.plot(dp_w16_n23_train['avg_actual_loss'], label="noise_mult 2.3")
plt.plot(dp_w16_n26_train['avg_actual_loss'], label="noise_mult 2.6")
plt.plot(dp_w16_n29_train['avg_actual_loss'], label="noise_mult 2.9")
plt.plot(dp_w16_n32_train['avg_actual_loss'], label="noise_mult 3.2")


plt.title("Training Curves for Width 16 Varying Noise, Weight Decay 0.0001")
plt.xlabel("epoch")
plt.ylabel('error')
plt.legend()

# %%
dp_w1_n05_train = pd.read_csv("logs/train_dp_w1_n05_reweight.csv")
dp_w1_n05_train = dp_w1_n05_train.groupby(['epoch']).mean()

dp_w1_n08_train = pd.read_csv("logs/train_dp_w1_n08_reweight.csv")
dp_w1_n08_train = dp_w1_n08_train.groupby(['epoch']).mean()

dp_w1_n11_train = pd.read_csv("logs/train_dp_w1_n11_reweight.csv")
dp_w1_n11_train = dp_w1_n11_train.groupby(['epoch']).mean()

dp_w1_n14_train = pd.read_csv("logs/train_dp_w1_n14_reweight.csv")
dp_w1_n14_train = dp_w1_n14_train.groupby(['epoch']).mean()

dp_w1_n17_train = pd.read_csv("logs/train_dp_w1_n17_reweight.csv")
dp_w1_n17_train = dp_w1_n17_train.groupby(['epoch']).mean()

dp_w1_n20_train = pd.read_csv("logs/train_dp_w1_n20_reweight.csv")
dp_w1_n20_train = dp_w1_n20_train.groupby(['epoch']).mean()

# %%
plt.plot(dp_w1_n05_train['avg_actual_loss'], label="noise_mult 0.5")
plt.plot(dp_w1_n08_train['avg_actual_loss'], label="noise_mult 0.8")
plt.plot(dp_w1_n11_train['avg_actual_loss'], label="noise_mult 1.1")
plt.plot(dp_w1_n14_train['avg_actual_loss'], label="noise_mult 1.4")
plt.plot(dp_w1_n17_train['avg_actual_loss'], label="noise_mult 1.7")
plt.plot(dp_w1_n20_train['avg_actual_loss'], label="noise_mult 2.0")

plt.title("Training Curves for Width 1 Varying Noise, Weight Decay 0.0001")
plt.xlabel("epoch")
plt.ylabel('error')
plt.legend()

# %%
dp_w4_n05_train = pd.read_csv("logs/train_dp_w4_n05_reweight.csv")
dp_w4_n05_train = dp_w4_n05_train.groupby(['epoch']).mean()

dp_w4_n08_train = pd.read_csv("logs/train_dp_w4_n08_reweight.csv")
dp_w4_n08_train = dp_w4_n08_train.groupby(['epoch']).mean()

dp_w4_n11_train = pd.read_csv("logs/train_dp_w4_n11_reweight.csv")
dp_w4_n11_train = dp_w4_n11_train.groupby(['epoch']).mean()

dp_w4_n14_train = pd.read_csv("logs/train_dp_w4_n14_reweight.csv")
dp_w4_n14_train = dp_w4_n14_train.groupby(['epoch']).mean()

dp_w4_n17_train = pd.read_csv("logs/train_dp_w4_n17_reweight.csv")
dp_w4_n17_train = dp_w4_n17_train.groupby(['epoch']).mean()

dp_w4_n20_train = pd.read_csv("logs/train_dp_w4_n20_reweight.csv")
dp_w4_n20_train = dp_w4_n20_train.groupby(['epoch']).mean()

# %%
plt.plot(dp_w4_n05_train['avg_actual_loss'], label="noise_mult 0.5")
plt.plot(dp_w4_n08_train['avg_actual_loss'], label="noise_mult 0.8")
plt.plot(dp_w4_n11_train['avg_actual_loss'], label="noise_mult 1.1")
plt.plot(dp_w4_n14_train['avg_actual_loss'], label="noise_mult 1.4")
plt.plot(dp_w4_n17_train['avg_actual_loss'], label="noise_mult 1.7")
plt.plot(dp_w4_n20_train['avg_actual_loss'], label="noise_mult 2.0")

plt.title("Training Curves for Width 4 Varying Noise, Weight Decay 0.0001")
plt.xlabel("epoch")
plt.ylabel('error')
plt.legend()

# %%
dp_w32_n05_train = pd.read_csv("logs/train_dp_w32_n05_reweight.csv")
dp_w32_n05_train = dp_w32_n05_train.groupby(['epoch']).mean()

dp_w32_n08_train = pd.read_csv("logs/train_dp_w32_n08_reweight.csv")
dp_w32_n08_train = dp_w32_n08_train.groupby(['epoch']).mean()

dp_w32_n11_train = pd.read_csv("logs/train_dp_w32_n11_reweight.csv")
dp_w32_n11_train = dp_w32_n11_train.groupby(['epoch']).mean()

dp_w32_n14_train = pd.read_csv("logs/train_dp_w32_n14_reweight.csv")
dp_w32_n14_train = dp_w32_n14_train.groupby(['epoch']).mean()

dp_w32_n17_train = pd.read_csv("logs/train_dp_w32_n17_reweight.csv")
dp_w32_n17_train = dp_w32_n17_train.groupby(['epoch']).mean()

dp_w32_n20_train = pd.read_csv("logs/train_dp_w32_n20_reweight.csv")
dp_w32_n20_train = dp_w32_n20_train.groupby(['epoch']).mean()

# %%
plt.plot(dp_w32_n05_train['avg_actual_loss'], label="noise_mult 0.5")
plt.plot(dp_w32_n08_train['avg_actual_loss'], label="noise_mult 0.8")
plt.plot(dp_w32_n11_train['avg_actual_loss'], label="noise_mult 1.1")
plt.plot(dp_w32_n14_train['avg_actual_loss'], label="noise_mult 1.4")
plt.plot(dp_w32_n17_train['avg_actual_loss'], label="noise_mult 1.7")
plt.plot(dp_w32_n20_train['avg_actual_loss'], label="noise_mult 2.0")

plt.title("Training Curves for Width 32 Varying Noise, Weight Decay 0.0001")
plt.xlabel("epoch")
plt.ylabel('error')
plt.legend()

# %%
dp_w64_n05_train = pd.read_csv("logs/train_dp_w64_n05_reweight.csv")
dp_w64_n05_train = dp_w64_n05_train.groupby(['epoch']).mean()

dp_w64_n08_train = pd.read_csv("logs/train_dp_w64_n08_reweight.csv")
dp_w64_n08_train = dp_w64_n08_train.groupby(['epoch']).mean()

dp_w64_n11_train = pd.read_csv("logs/train_dp_w64_n11_reweight.csv")
dp_w64_n11_train = dp_w64_n11_train.groupby(['epoch']).mean()

dp_w64_n14_train = pd.read_csv("logs/train_dp_w64_n14_reweight.csv")
dp_w64_n14_train = dp_w64_n14_train.groupby(['epoch']).mean()

dp_w64_n17_train = pd.read_csv("logs/train_dp_w64_n17_reweight.csv")
dp_w64_n17_train = dp_w64_n17_train.groupby(['epoch']).mean()

dp_w64_n20_train = pd.read_csv("logs/train_dp_w64_n20_reweight.csv")
dp_w64_n20_train = dp_w64_n20_train.groupby(['epoch']).mean()

# %%
plt.plot(dp_w64_n05_train['avg_actual_loss'], label="noise_mult 0.5")
plt.plot(dp_w64_n08_train['avg_actual_loss'], label="noise_mult 0.8")
plt.plot(dp_w64_n11_train['avg_actual_loss'], label="noise_mult 1.1")
plt.plot(dp_w64_n14_train['avg_actual_loss'], label="noise_mult 1.4")
plt.plot(dp_w64_n17_train['avg_actual_loss'], label="noise_mult 1.7")
plt.plot(dp_w64_n20_train['avg_actual_loss'], label="noise_mult 2.0")

plt.title("Training Curves for Width 64 Varying Noise, Weight Decay 0.0001")
plt.xlabel("epoch")
plt.ylabel('error')
plt.legend()

# %%
dp_w96_n05_train = pd.read_csv("logs/train_dp_w96_n05_reweight.csv")
dp_w96_n05_train = dp_w96_n05_train.groupby(['epoch']).mean()

dp_w96_n08_train = pd.read_csv("logs/train_dp_w96_n08_reweight.csv")
dp_w96_n08_train = dp_w96_n08_train.groupby(['epoch']).mean()

dp_w96_n11_train = pd.read_csv("logs/train_dp_w96_n11_reweight.csv")
dp_w96_n11_train = dp_w96_n11_train.groupby(['epoch']).mean()

dp_w96_n14_train = pd.read_csv("logs/train_dp_w96_n14_reweight.csv")
dp_w96_n14_train = dp_w96_n14_train.groupby(['epoch']).mean()

dp_w96_n17_train = pd.read_csv("logs/train_dp_w96_n17_reweight.csv")
dp_w96_n17_train = dp_w96_n17_train.groupby(['epoch']).mean()

dp_w96_n20_train = pd.read_csv("logs/train_dp_w96_n20_reweight.csv")
dp_w96_n20_train = dp_w96_n20_train.groupby(['epoch']).mean()

# %%
plt.plot(dp_w96_n05_train['avg_actual_loss'], label="noise_mult 0.5")
plt.plot(dp_w96_n08_train['avg_actual_loss'], label="noise_mult 0.8")
plt.plot(dp_w96_n11_train['avg_actual_loss'], label="noise_mult 1.1")
plt.plot(dp_w96_n14_train['avg_actual_loss'], label="noise_mult 1.4")
plt.plot(dp_w96_n17_train['avg_actual_loss'], label="noise_mult 1.7")
plt.plot(dp_w96_n20_train['avg_actual_loss'], label="noise_mult 2.0")

plt.title("Training Curves for Width 96 Varying Noise, Weight Decay 0.0001")
plt.xlabel("epoch")
plt.ylabel('error')
plt.legend()
