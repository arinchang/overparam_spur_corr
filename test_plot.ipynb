# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
test_df = pd.read_csv("logs/test.csv")
test_df.head()
# Out:
#    epoch  batch  avg_loss_group:0  exp_avg_loss_group:0  avg_acc_group:0  \
# 0      0    155          0.207933              0.224819         0.917784
# 1      1    155          0.104421              0.113814         0.959455
# 2      2    155          0.213036              0.211619         0.922392
# 3      3    155          0.314123              0.345759         0.893417
# 4      4    155          0.309331              0.320279         0.898843
#
#    processed_data_count_group:0  update_data_count_group:0  \
# 0                        9767.0                     9767.0
# 1                        9767.0                     9767.0
# 2                        9767.0                     9767.0
# 3                        9767.0                     9767.0
# 4                        9767.0                     9767.0
#
#    update_batch_count_group:0  avg_loss_group:1  exp_avg_loss_group:1  ...  \
# 0                       156.0          0.124586              0.121827  ...
# ...

# %%
train_df = pd.read_csv("logs/train.csv")
train_df.head()
# Out:
#    epoch  batch  avg_loss_group:0  exp_avg_loss_group:0  avg_acc_group:0  \
# 0      0     49          0.489907              0.490783         0.774780
# 1      0     99          0.363500              0.382912         0.841270
# 2      0    149          0.316812              0.293031         0.865811
# 3      0    199          0.351632              0.335250         0.858312
# 4      0    249          0.362510              0.358812         0.837147
#
#    processed_data_count_group:0  update_data_count_group:0  \
# 0                        1594.0                     1594.0
# 1                        1575.0                     1575.0
# 2                        1714.0                     1714.0
# 3                        1588.0                     1588.0
# 4                        1486.0                     1486.0
#
#    update_batch_count_group:0  avg_loss_group:1  exp_avg_loss_group:1  ...  \
# 0                        50.0          0.547974              0.534541  ...
# ...

# %%
val_df = pd.read_csv("logs/val.csv")
val_df.head()
# Out:
#    epoch  batch  avg_loss_group:0  exp_avg_loss_group:0  avg_acc_group:0  \
# 0      0    155          0.252546              0.261293         0.894786
# 1      1    155          0.130435              0.128292         0.946573
# 2      2    155          0.269364              0.285413         0.895841
# 3      3    155          0.383706              0.434922         0.865495
# 4      4    155          0.393718              0.417275         0.869244
#
#    processed_data_count_group:0  update_data_count_group:0  \
# 0                        8535.0                     8535.0
# 1                        8535.0                     8535.0
# 2                        8535.0                     8535.0
# 3                        8535.0                     8535.0
# 4                        8535.0                     8535.0
#
#    update_batch_count_group:0  avg_loss_group:1  exp_avg_loss_group:1  ...  \
# 0                       156.0          0.126463              0.107594  ...
# ...

# %%
plt.style.use('dark_background')
plt.plot(np.arange(50), test_df["avg_loss_group:0"])
plt.show()

# %%
plt.style.use('dark_background')
plt.plot(np.arange(50), test_df["avg_loss_group:1"])
plt.show()

# %%
plt.style.use('dark_background')
plt.plot(np.arange(50), test_df["avg_loss_group:2"])
plt.show()

# %%
plt.style.use('dark_background')
plt.plot(np.arange(50), test_df["avg_loss_group:3"])
plt.show()

# %%
plt.style.use('dark_background')
plt.plot(np.arange(50), test_df["avg_actual_loss"])
plt.show()

# %% [markdown]
# ## DP vs non-DP Resnet10 with width32

# %%
dp_train_df = pd.read_csv("logs/train_0.csv")
dp_train_df.head()
# Out:
#    epoch  batch  avg_loss_group:0  exp_avg_loss_group:0  avg_acc_group:0  \
# 0      0     49          0.972790              0.924707         0.002509
# 1      0     99          1.239141              1.377795         0.000000
# 2      0    149          0.461051              0.102508         0.711785
# 3      0    199          0.130760              0.304248         0.971033
# 4      0    249          1.442364              1.419313         0.297443
#
#    processed_data_count_group:0  update_data_count_group:0  \
# 0                        1594.0                     1594.0
# 1                        1575.0                     1575.0
# 2                        1714.0                     1714.0
# 3                        1588.0                     1588.0
# 4                        1486.0                     1486.0
#
#    update_batch_count_group:0  avg_loss_group:1  exp_avg_loss_group:1  ...  \
# 0                        50.0          0.987361              0.944506  ...
# ...

# %%
dp_test_df = pd.read_csv("logs/test_0.csv")
dp_test_df.head()
# Out:
#    epoch  batch  avg_loss_group:0  exp_avg_loss_group:0  avg_acc_group:0  \
# 0      0    155          0.832542              0.846283         0.792772
# 1      1    155          0.726978              0.738151         0.827480
# 2      2    155          0.828795              0.817020         0.822259
# 3      3    155          0.710073              0.685903         0.849903
# 4      4    155          0.680900              0.676327         0.855022
#
#    processed_data_count_group:0  update_data_count_group:0  \
# 0                        9767.0                     9767.0
# 1                        9767.0                     9767.0
# 2                        9767.0                     9767.0
# 3                        9767.0                     9767.0
# 4                        9767.0                     9767.0
#
#    update_batch_count_group:0  avg_loss_group:1  exp_avg_loss_group:1  ...  \
# 0                       156.0          0.818909              0.769931  ...
# ...

# %%
dp_val_df = pd.read_csv("logs/val_0.csv")
dp_val_df.head()
# Out:
#    epoch  batch  avg_loss_group:0  exp_avg_loss_group:0  avg_acc_group:0  \
# 0      0    155          1.010536              0.993706         0.755478
# 1      1    155          0.905091              0.904809         0.789338
# 2      2    155          1.014062              1.061034         0.783246
# 3      3    155          0.901441              0.962212         0.809608
# 4      4    155          0.848217              0.903960         0.822379
#
#    processed_data_count_group:0  update_data_count_group:0  \
# 0                        8535.0                     8535.0
# 1                        8535.0                     8535.0
# 2                        8535.0                     8535.0
# 3                        8535.0                     8535.0
# 4                        8535.0                     8535.0
#
#    update_batch_count_group:0  avg_loss_group:1  exp_avg_loss_group:1  ...  \
# 0                       156.0          0.803923              0.724794  ...
# ...

# %%
plt.plot(dp_test_df["avg_actual_loss"])
plt.title("Resnet10 on celebA with width32 and DP")
# Out:
# Text(0.5, 1.0, 'Resnet10 on celebA with width32 and DP')

# %%
test_32_df = pd.read_csv("logs/test_4.csv")
test_32_df.head()
# Out:
#    epoch  batch  avg_loss_group:0  exp_avg_loss_group:0  avg_acc_group:0  \
# 0      0    155          0.207933              0.224819         0.917784
# 1      1    155          0.104421              0.113814         0.959455
# 2      2    155          0.213036              0.211619         0.922392
# 3      3    155          0.314123              0.345759         0.893417
# 4      4    155          0.309331              0.320279         0.898843
#
#    processed_data_count_group:0  update_data_count_group:0  \
# 0                        9767.0                     9767.0
# 1                        9767.0                     9767.0
# 2                        9767.0                     9767.0
# 3                        9767.0                     9767.0
# 4                        9767.0                     9767.0
#
#    update_batch_count_group:0  avg_loss_group:1  exp_avg_loss_group:1  ...  \
# 0                       156.0          0.124586              0.121827  ...
# ...

# %%
plt.plot(test_32_df["avg_actual_loss"])
plt.title("Resnet10 on celebA with width32")
# Out:
# Text(0.5, 1.0, 'Resnet10 on celebA with width32')
