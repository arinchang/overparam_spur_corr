# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
test_df = pd.read_csv("logs/test.csv")
test_df.head()
# Out:
#    epoch  batch  avg_loss_group:0  exp_avg_loss_group:0  avg_acc_group:0  \
# 0      0    155          0.207933              0.224819         0.917784
# 1      1    155          0.104421              0.113814         0.959455
# 2      2    155          0.213036              0.211619         0.922392
# 3      3    155          0.314123              0.345759         0.893417
# 4      4    155          0.309331              0.320279         0.898843
#
#    processed_data_count_group:0  update_data_count_group:0  \
# 0                        9767.0                     9767.0
# 1                        9767.0                     9767.0
# 2                        9767.0                     9767.0
# 3                        9767.0                     9767.0
# 4                        9767.0                     9767.0
#
#    update_batch_count_group:0  avg_loss_group:1  exp_avg_loss_group:1  \
# 0                       156.0          0.124586              0.121827
# 1                       156.0          0.039827              0.038237
# 2                       156.0          0.125499              0.144664
# 3                       156.0          0.093978              0.080228
# 4                       156.0          0.118203              0.106424
#
#      ...     exp_avg_loss_group:3  avg_acc_group:3  \
# 0    ...                 0.371994         0.716667
# 1    ...                 1.500760         0.438889
# 2    ...                 1.051884         0.644445
# 3    ...                 0.947752         0.633334
# 4    ...                 0.843549         0.716667
#
#    processed_data_count_group:3  update_data_count_group:3  \
# 0                         180.0                      180.0
# 1                         180.0                      180.0
# 2                         180.0                      180.0
# 3                         180.0                      180.0
# 4                         180.0                      180.0
#
#    update_batch_count_group:3  avg_actual_loss  avg_per_sample_loss   avg_acc  \
# 0                       107.0         0.185032             0.185026  0.927512
# 1                       107.0         0.139248             0.139228  0.947901
# 2                       107.0         0.198758             0.198736  0.926060
# 3                       107.0         0.220641             0.220631  0.923354
# 4                       107.0         0.228161             0.228164  0.921751
#
#    model_norm_sq  reg_loss
# 0    3304.619385  0.165231
# 1    3249.444336  0.162472
# 2    3196.281250  0.159814
# 3    3145.030518  0.157252
# 4    3096.351074  0.154818
#
# [5 rows x 31 columns]

# %%
train_df = pd.read_csv("logs/train.csv")
train_df.head()
# Out:
#    epoch  batch  avg_loss_group:0  exp_avg_loss_group:0  avg_acc_group:0  \
# 0      0     49          0.489907              0.490783         0.774780
# 1      0     99          0.363500              0.382912         0.841270
# 2      0    149          0.316812              0.293031         0.865811
# 3      0    199          0.351632              0.335250         0.858312
# 4      0    249          0.362510              0.358812         0.837147
#
#    processed_data_count_group:0  update_data_count_group:0  \
# 0                        1594.0                     1594.0
# 1                        1575.0                     1575.0
# 2                        1714.0                     1714.0
# 3                        1588.0                     1588.0
# 4                        1486.0                     1486.0
#
#    update_batch_count_group:0  avg_loss_group:1  exp_avg_loss_group:1  \
# 0                        50.0          0.547974              0.534541
# 1                        50.0          0.415216              0.396942
# 2                        50.0          0.338039              0.339027
# 3                        50.0          0.357283              0.331383
# 4                        50.0          0.344261              0.319049
#
#      ...     exp_avg_loss_group:3  avg_acc_group:3  \
# 0    ...                 0.498744         0.651592
# 1    ...                 0.418351         0.768044
# 2    ...                 0.426078         0.819389
# 3    ...                 0.374872         0.827431
# 4    ...                 0.291737         0.867960
#
#    processed_data_count_group:3  update_data_count_group:3  \
# 0                        1570.0                     1570.0
# 1                        1621.0                     1621.0
# 2                        1506.0                     1506.0
# 3                        1553.0                     1553.0
# 4                        1598.0                     1598.0
#
#    update_batch_count_group:3  avg_actual_loss  avg_per_sample_loss   avg_acc  \
# 0                        50.0         0.517237             0.517237  0.737656
# 1                        50.0         0.379787             0.379786  0.833125
# 2                        50.0         0.337421             0.337421  0.859531
# 3                        50.0         0.336569             0.336569  0.858281
# 4                        50.0         0.318497             0.318497  0.868906
#
#    model_norm_sq  reg_loss
# 0    3364.717041  0.168236
# 1    3362.288818  0.168114
# 2    3359.942139  0.167997
# 3    3357.340576  0.167867
# 4    3354.608643  0.167730
#
# [5 rows x 31 columns]

# %%
val_df = pd.read_csv("logs/val.csv")
val_df.head()
# Out:
#    epoch  batch  avg_loss_group:0  exp_avg_loss_group:0  avg_acc_group:0  \
# 0      0    155          0.252546              0.261293         0.894786
# 1      1    155          0.130435              0.128292         0.946573
# 2      2    155          0.269364              0.285413         0.895841
# 3      3    155          0.383706              0.434922         0.865495
# 4      4    155          0.393718              0.417275         0.869244
#
#    processed_data_count_group:0  update_data_count_group:0  \
# 0                        8535.0                     8535.0
# 1                        8535.0                     8535.0
# 2                        8535.0                     8535.0
# 3                        8535.0                     8535.0
# 4                        8535.0                     8535.0
#
#    update_batch_count_group:0  avg_loss_group:1  exp_avg_loss_group:1  \
# 0                       156.0          0.126463              0.107594
# 1                       156.0          0.042826              0.041333
# 2                       156.0          0.129358              0.097517
# 3                       156.0          0.104298              0.088045
# 4                       156.0          0.135932              0.125927
#
#      ...     exp_avg_loss_group:3  avg_acc_group:3  \
# 0    ...                 0.685842         0.763736
# 1    ...                 1.168900         0.532967
# 2    ...                 0.636272         0.642857
# 3    ...                 0.658822         0.692308
# 4    ...                 0.795406         0.703297
#
#    processed_data_count_group:3  update_data_count_group:3  \
# 0                         182.0                      182.0
# 1                         182.0                      182.0
# 2                         182.0                      182.0
# 3                         182.0                      182.0
# 4                         182.0                      182.0
#
#    update_batch_count_group:3  avg_actual_loss  avg_per_sample_loss   avg_acc  \
# 0                       100.0         0.200586             0.200394  0.917904
# 1                       100.0         0.146512             0.146348  0.942870
# 2                       100.0         0.215183             0.215053  0.915740
# 3                       100.0         0.239391             0.238501  0.915337
# 4                       100.0         0.258002             0.257392  0.911864
#
#    model_norm_sq  reg_loss
# 0    3304.619385  0.165231
# 1    3249.444336  0.162472
# 2    3196.281250  0.159814
# 3    3145.030518  0.157252
# 4    3096.351074  0.154818
#
# [5 rows x 31 columns]

# %%
plt.style.use('dark_background')
plt.plot(np.arange(50), test_df["avg_loss_group:0"])
plt.show()

# %%
plt.style.use('dark_background')
plt.plot(np.arange(50), test_df["avg_loss_group:1"])
plt.show()

# %%
plt.style.use('dark_background')
plt.plot(np.arange(50), test_df["avg_loss_group:2"])
plt.show()

# %%
plt.style.use('dark_background')
plt.plot(np.arange(50), test_df["avg_loss_group:3"])
plt.show()

# %%
plt.style.use('dark_background')
plt.plot(np.arange(50), test_df["avg_actual_loss"])
plt.show()
